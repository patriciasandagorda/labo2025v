# %% [markdown]
# <a href="https://colab.research.google.com/github/patriciasandagorda/labo2025v/blob/main/src/ensembles/594_TareaHogar_05_ITERACION50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea para el Hogar 05

# %% [markdown]
# Esta Tarea para el Hogar 05 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el miercoles 03 de septiembre

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/austral2025-af91/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Nov 04 03:07:19 AM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660381 35.3 1454465    77.7 1454465  77.7
# Vcells 1226627  9.4 8388608    64.0 1975128  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- "5940_2"
PARAM$semilla_primigenia <- 999961

# %%
PARAM$kaggle$competencia <- "labo-i-2025-virtual-analista-sr"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_iterations", lower= 8L, upper= 2048L),
  makeNumericParam("learning_rate", lower= 0.01, upper= 0.3),
  makeNumericParam("feature_fraction", lower= 0.1, upper= 1.0),
  makeIntegerParam("num_leaves", lower= 8L, upper= 2048L),
  makeIntegerParam("min_data_in_leaf", lower= 1L, upper= 8000L)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 50 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83435
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Tue Nov 04 03:33:31 AM 2025 AUC 0.924659596007122
#
# Tue Nov 04 03:35:54 AM 2025 AUC 0.924426046663315
#
# Tue Nov 04 03:40:58 AM 2025 AUC 0.92603679073753
#
# Tue Nov 04 03:46:51 AM 2025 AUC 0.925945390833588
#
# Tue Nov 04 03:48:15 AM 2025 AUC 0.923231761441527
#
# Tue Nov 04 03:51:20 AM 2025 AUC 0.925535444530948
#
# Tue Nov 04 03:52:43 AM 2025 AUC 0.924734271513014
#
# Tue Nov 04 03:53:46 AM 2025 AUC 0.928311082845634
#
# Tue Nov 04 03:59:52 AM 2025 AUC 0.926957244902875
#
# Tue Nov 04 04:06:16 AM 2025 AUC 0.92741278534852
#
# Tue Nov 04 04:08:09 AM 2025 AUC 0.922887550744791
#
# Tue Nov 04 04:11:08 AM 2025 AUC 0.925057924434872
#
# Tue Nov 04 04:15:34 AM 2025 AUC 0.922687133319987
#
# Tue Nov 04 04:17:46 AM 2025 AUC 0.925258496894899
#
# Tue Nov 04 04:21:27 AM 2025 AUC 0.923698798415125
#
# Tue Nov 04 04:30:11 AM 2025 AUC 0.928307114830801
#
# Tue Nov 04 04:37:30 AM 2025 AUC 0.924991648289359
#
# Tue Nov 04 04:37:38 AM 2025 AUC 0.916866295230448
#
# Tue Nov 04 04:38:28 AM 2025 AUC 0.925307633645515
#
# Tue Nov 04 04:45:22 AM 2025 AUC 0.925118016571904
#
# [mbo] 0: num_iterations=1449; learning_rate=0.167; feature_fraction=0.57; num_leaves=869; min_data_in_leaf=2007 : y = 0.925 : 410.7 secs : initdesign
#
# [mbo] 0: num_iterations=564; learning_rate=0.179; feature_fraction=0.39; num_leaves=136; min_data_in_leaf=3038 : y = 0.924 : 143.5 secs : initdesign
#
# [mbo] 0: num_iterations=1120; learning_rate=0.242; feature_fraction=0.508; num_leaves=1477; min_data_in_leaf=4026 : y = 0.926 : 303.8 secs : initdesign
#
# [mbo] 0: num_iterations=2030; learning_rate=0.211; feature_fraction=0.665; num_leaves=1278; min_data_in_leaf=4577 : y = 0.926 : 353.4 secs : initdesign
#
# [mbo] 0: num_iterations=428; learning_rate=0.215; feature_fraction=0.193; num_leaves=34; min_data_in_leaf=4970 : y = 0.923 : 84.2 secs : initdesign
#
# [mbo] 0: num_iterations=1018; learning_rate=0.282; feature_fraction=0.92; num_leaves=1139; min_data_in_leaf=3800 : y = 0.926 : 185.1 secs : initdesign
#
# [mbo] 0: num_iterations=364; learning_rate=0.0983; feature_fraction=0.331; num_leaves=1088; min_data_in_leaf=6187 : y = 0.925 : 82.0 secs : initdesign
#
# [mbo] 0: num_iterations=255; learning_rate=0.0217; feature_fraction=0.884; num_leaves=818; min_data_in_leaf=1268 : y = 0.928 : 63.3 secs : initdesign
#
# [mbo] 0: num_iterations=1317; learning_rate=0.121; feature_fraction=0.49; num_leaves=940; min_data_in_leaf=3338 : y = 0.927 : 366.5 secs : initdesign
#
# [mbo] 0: num_iterations=1767; learning_rate=0.0958; feature_fraction=0.859; num_leaves=514; min_data_in_leaf=1989 : y = 0.927 : 383.4 secs : initdesign
#
# [mbo] 0: num_iterations=630; learning_rate=0.246; feature_fraction=0.153; num_leaves=1429; min_data_in_leaf=5519 : y = 0.923 : 113.0 secs : initdesign
#
# [mbo] 0: num_iterations=881; learning_rate=0.0527; feature_fraction=0.235; num_leaves=1893; min_data_in_leaf=5858 : y = 0.925 : 178.9 secs : initdesign
#
# [mbo] 0: num_iterations=1135; learning_rate=0.14; feature_fraction=0.144; num_leaves=579; min_data_in_leaf=573 : y = 0.923 : 266.6 secs : initdesign
#
# [mbo] 0: num_iterations=803; learning_rate=0.0549; feature_fraction=0.968; num_leaves=1757; min_data_in_leaf=6450 : y = 0.925 : 132.3 secs : initdesign
#
# [mbo] 0: num_iterations=1406; learning_rate=0.296; feature_fraction=0.743; num_leaves=1735; min_data_in_leaf=7355 : y = 0.924 : 220.5 secs : initdesign
#
# [mbo] 0: num_iterations=1563; learning_rate=0.0321; feature_fraction=0.301; num_leaves=1984; min_data_in_leaf=360 : y = 0.928 : 524.0 secs : initdesign
#
# [mbo] 0: num_iterations=1910; learning_rate=0.261; feature_fraction=0.608; num_leaves=264; min_data_in_leaf=2688 : y = 0.925 : 439.2 secs : initdesign
#
# [mbo] 0: num_iterations=29; learning_rate=0.147; feature_fraction=0.795; num_leaves=399; min_data_in_leaf=6915 : y = 0.917 : 8.3 secs : initdesign
#
# [mbo] 0: num_iterations=184; learning_rate=0.193; feature_fraction=0.691; num_leaves=1547; min_data_in_leaf=1067 : y = 0.925 : 49.3 secs : initdesign
#
# [mbo] 0: num_iterations=1723; learning_rate=0.0795; feature_fraction=0.458; num_leaves=652; min_data_in_leaf=7621 : y = 0.925 : 414.7 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Tue Nov 04 04:50:35 AM 2025 AUC 0.926508642937986
#
# [mbo] 1: num_iterations=1338; learning_rate=0.0338; feature_fraction=0.838; num_leaves=1175; min_data_in_leaf=1571 : y = 0.927 : 311.9 secs : infill_ei
#
# Tue Nov 04 04:53:11 AM 2025 AUC 0.929344582940496
#
# [mbo] 2: num_iterations=414; learning_rate=0.0225; feature_fraction=0.404; num_leaves=1849; min_data_in_leaf=340 : y = 0.929 : 155.3 secs : infill_ei
#
# Tue Nov 04 04:55:06 AM 2025 AUC 0.921374000518459
#
# [mbo] 3: num_iterations=243; learning_rate=0.0164; feature_fraction=0.187; num_leaves=753; min_data_in_leaf=9 : y = 0.921 : 114.3 secs : infill_ei
#
# Tue Nov 04 05:01:49 AM 2025 AUC 0.929444346208484
#
# [mbo] 4: num_iterations=1184; learning_rate=0.0212; feature_fraction=0.416; num_leaves=2048; min_data_in_leaf=572 : y = 0.929 : 402.9 secs : infill_ei
#
# Saved the current state after iteration 5 in the file bayesiana.RDATA.
#
# Tue Nov 04 05:15:41 AM 2025 AUC 0.925939219642701
#
# [mbo] 5: num_iterations=678; learning_rate=0.0119; feature_fraction=0.447; num_leaves=2020; min_data_in_leaf=16 : y = 0.926 : 830.3 secs : infill_ei
#
# Saved the current state after iteration 6 in the file bayesiana.RDATA.
#
# Tue Nov 04 05:20:37 AM 2025 AUC 0.926262659911197
#
# [mbo] 6: num_iterations=889; learning_rate=0.0975; feature_fraction=0.378; num_leaves=1919; min_data_in_leaf=562 : y = 0.926 : 296.2 secs : infill_ei
#
# Tue Nov 04 05:29:15 AM 2025 AUC 0.929584109557869
#
# [mbo] 7: num_iterations=1528; learning_rate=0.0174; feature_fraction=0.41; num_leaves=1779; min_data_in_leaf=659 : y = 0.93 : 516.7 secs : infill_ei
#
# Saved the current state after iteration 8 in the file bayesiana.RDATA.
#
# Tue Nov 04 05:34:37 AM 2025 AUC 0.929175500376749
#
# [mbo] 8: num_iterations=1045; learning_rate=0.0127; feature_fraction=0.408; num_leaves=1744; min_data_in_leaf=1004 : y = 0.929 : 321.5 secs : infill_ei
#
# Tue Nov 04 05:42:16 AM 2025 AUC 0.927599049063345
#
# [mbo] 9: num_iterations=1258; learning_rate=0.0797; feature_fraction=0.413; num_leaves=1419; min_data_in_leaf=317 : y = 0.928 : 458.8 secs : infill_ei
#
# Saved the current state after iteration 10 in the file bayesiana.RDATA.
#
# Tue Nov 04 05:51:04 AM 2025 AUC 0.929623516844339
#
# [mbo] 10: num_iterations=1478; learning_rate=0.0101; feature_fraction=0.402; num_leaves=2005; min_data_in_leaf=420 : y = 0.93 : 527.1 secs : infill_ei
#
# Tue Nov 04 05:53:37 AM 2025 AUC 0.929550451717262
#
# [mbo] 11: num_iterations=434; learning_rate=0.0103; feature_fraction=0.431; num_leaves=1567; min_data_in_leaf=508 : y = 0.93 : 151.9 secs : infill_ei
#
# Saved the current state after iteration 12 in the file bayesiana.RDATA.
#
# Tue Nov 04 05:54:51 AM 2025 AUC 0.924365959094236
#
# [mbo] 12: num_iterations=198; learning_rate=0.0104; feature_fraction=0.422; num_leaves=1078; min_data_in_leaf=397 : y = 0.924 : 73.5 secs : infill_ei
#
# Tue Nov 04 05:56:41 AM 2025 AUC 0.927327446835895
#
# [mbo] 13: num_iterations=410; learning_rate=0.0105; feature_fraction=0.771; num_leaves=1779; min_data_in_leaf=1008 : y = 0.927 : 109.5 secs : infill_ei
#
# Tue Nov 04 06:03:47 AM 2025 AUC 0.929166554609922
#
# [mbo] 14: num_iterations=1341; learning_rate=0.0114; feature_fraction=0.42; num_leaves=2046; min_data_in_leaf=906 : y = 0.929 : 426.0 secs : infill_ei
#
# Saved the current state after iteration 15 in the file bayesiana.RDATA.
#
# Tue Nov 04 06:06:02 AM 2025 AUC 0.929047135344809
#
# [mbo] 15: num_iterations=443; learning_rate=0.0182; feature_fraction=0.422; num_leaves=1787; min_data_in_leaf=1195 : y = 0.929 : 134.3 secs : infill_ei
#
# Tue Nov 04 06:16:25 AM 2025 AUC 0.922609227333415
#
# [mbo] 16: num_iterations=1811; learning_rate=0.106; feature_fraction=0.411; num_leaves=1948; min_data_in_leaf=48 : y = 0.923 : 622.2 secs : infill_ei
#
# Saved the current state after iteration 17 in the file bayesiana.RDATA.
#
# Tue Nov 04 06:18:49 AM 2025 AUC 0.930046122924857
#
# [mbo] 17: num_iterations=427; learning_rate=0.0332; feature_fraction=0.395; num_leaves=1672; min_data_in_leaf=601 : y = 0.93 : 143.7 secs : infill_ei
#
# Tue Nov 04 06:20:51 AM 2025 AUC 0.928684684411216
#
# [mbo] 18: num_iterations=380; learning_rate=0.01; feature_fraction=0.368; num_leaves=1834; min_data_in_leaf=614 : y = 0.929 : 121.2 secs : infill_ei
#
# Tue Nov 04 06:26:48 AM 2025 AUC 0.926147572296605
#
# [mbo] 19: num_iterations=414; learning_rate=0.05; feature_fraction=0.484; num_leaves=1579; min_data_in_leaf=18 : y = 0.926 : 356.6 secs : infill_ei
#
# Saved the current state after iteration 20 in the file bayesiana.RDATA.
#
# Tue Nov 04 06:29:49 AM 2025 AUC 0.930901046719846
#
# [mbo] 20: num_iterations=516; learning_rate=0.031; feature_fraction=0.422; num_leaves=1782; min_data_in_leaf=567 : y = 0.931 : 179.7 secs : infill_ei
#
# Tue Nov 04 06:32:43 AM 2025 AUC 0.929057340589137
#
# [mbo] 21: num_iterations=488; learning_rate=0.0416; feature_fraction=0.479; num_leaves=1732; min_data_in_leaf=763 : y = 0.929 : 173.9 secs : infill_ei
#
# Tue Nov 04 06:36:26 AM 2025 AUC 0.928633794220427
#
# [mbo] 22: num_iterations=535; learning_rate=0.0303; feature_fraction=0.391; num_leaves=1552; min_data_in_leaf=272 : y = 0.929 : 222.4 secs : infill_ei
#
# Tue Nov 04 06:43:26 AM 2025 AUC 0.929095598168618
#
# [mbo] 23: num_iterations=1123; learning_rate=0.031; feature_fraction=0.438; num_leaves=1744; min_data_in_leaf=472 : y = 0.929 : 418.9 secs : infill_ei
#
# Saved the current state after iteration 24 in the file bayesiana.RDATA.
#
# Tue Nov 04 06:51:13 AM 2025 AUC 0.930124220327018
#
# [mbo] 24: num_iterations=1401; learning_rate=0.0119; feature_fraction=0.385; num_leaves=330; min_data_in_leaf=567 : y = 0.93 : 466.2 secs : infill_ei
#
# Tue Nov 04 06:59:16 AM 2025 AUC 0.929430469454805
#
# [mbo] 25: num_iterations=1454; learning_rate=0.0154; feature_fraction=0.524; num_leaves=466; min_data_in_leaf=976 : y = 0.929 : 482.5 secs : infill_ei
#
# Saved the current state after iteration 26 in the file bayesiana.RDATA.
#
# Tue Nov 04 07:06:09 AM 2025 AUC 0.928920512829275
#
# [mbo] 26: num_iterations=1481; learning_rate=0.0103; feature_fraction=0.403; num_leaves=330; min_data_in_leaf=1576 : y = 0.929 : 412.7 secs : infill_ei
#
# Tue Nov 04 07:08:11 AM 2025 AUC 0.928782055755452
#
# [mbo] 27: num_iterations=534; learning_rate=0.0231; feature_fraction=0.634; num_leaves=51; min_data_in_leaf=1896 : y = 0.929 : 121.5 secs : infill_ei
#
# Tue Nov 04 07:15:24 AM 2025 AUC 0.929961219353873
#
# [mbo] 28: num_iterations=1302; learning_rate=0.0243; feature_fraction=0.46; num_leaves=196; min_data_in_leaf=735 : y = 0.93 : 432.1 secs : infill_ei
#
# Saved the current state after iteration 29 in the file bayesiana.RDATA.
#
# Tue Nov 04 07:26:16 AM 2025 AUC 0.929958202396574
#
# [mbo] 29: num_iterations=1888; learning_rate=0.0103; feature_fraction=0.442; num_leaves=326; min_data_in_leaf=600 : y = 0.93 : 651.1 secs : infill_ei
#
# Saved the current state after iteration 30 in the file bayesiana.RDATA.
#
# Tue Nov 04 07:33:00 AM 2025 AUC 0.931350991743748
#
# [mbo] 30: num_iterations=1649; learning_rate=0.0208; feature_fraction=0.47; num_leaves=14; min_data_in_leaf=475 : y = 0.931 : 404.0 secs : infill_ei
#
# Tue Nov 04 07:39:40 AM 2025 AUC 0.930774606660548
#
# [mbo] 31: num_iterations=1803; learning_rate=0.0106; feature_fraction=0.408; num_leaves=8; min_data_in_leaf=477 : y = 0.931 : 398.8 secs : infill_ei
#
# Saved the current state after iteration 32 in the file bayesiana.RDATA.
#
# Tue Nov 04 07:44:00 AM 2025 AUC 0.930304368043172
#
# [mbo] 32: num_iterations=1681; learning_rate=0.0109; feature_fraction=0.621; num_leaves=8; min_data_in_leaf=487 : y = 0.93 : 258.8 secs : infill_ei
#
# Tue Nov 04 07:51:27 AM 2025 AUC 0.931711618345193
#
# [mbo] 33: num_iterations=1638; learning_rate=0.0191; feature_fraction=0.34; num_leaves=53; min_data_in_leaf=631 : y = 0.932 : 446.8 secs : infill_ei
#
# Saved the current state after iteration 34 in the file bayesiana.RDATA.
#
# Tue Nov 04 07:56:04 AM 2025 AUC 0.930828843179921
#
# [mbo] 34: num_iterations=1681; learning_rate=0.0227; feature_fraction=0.145; num_leaves=10; min_data_in_leaf=602 : y = 0.931 : 276.4 secs : infill_ei
#
# Tue Nov 04 08:05:12 AM 2025 AUC 0.928298001587058
#
# [mbo] 35: num_iterations=1448; learning_rate=0.0181; feature_fraction=0.951; num_leaves=361; min_data_in_leaf=389 : y = 0.928 : 546.9 secs : infill_ei
#
# Saved the current state after iteration 36 in the file bayesiana.RDATA.
#
# Tue Nov 04 08:11:19 AM 2025 AUC 0.929927268632357
#
# [mbo] 36: num_iterations=1688; learning_rate=0.0287; feature_fraction=0.36; num_leaves=10; min_data_in_leaf=699 : y = 0.93 : 365.3 secs : infill_ei
#
# Tue Nov 04 08:12:31 AM 2025 AUC 0.928999012918735
#
# [mbo] 37: num_iterations=215; learning_rate=0.0314; feature_fraction=0.571; num_leaves=1988; min_data_in_leaf=1071 : y = 0.929 : 72.2 secs : infill_ei
#
# Tue Nov 04 08:19:52 AM 2025 AUC 0.929102836907579
#
# [mbo] 38: num_iterations=1679; learning_rate=0.0166; feature_fraction=0.291; num_leaves=99; min_data_in_leaf=4 : y = 0.929 : 439.8 secs : infill_ei
#
# Saved the current state after iteration 39 in the file bayesiana.RDATA.
#
# Tue Nov 04 08:22:19 AM 2025 AUC 0.928793789697177
#
# [mbo] 39: num_iterations=446; learning_rate=0.0308; feature_fraction=0.482; num_leaves=1872; min_data_in_leaf=1028 : y = 0.929 : 146.5 secs : infill_ei
#
# Tue Nov 04 08:24:31 AM 2025 AUC 0.927762736120809
#
# [mbo] 40: num_iterations=555; learning_rate=0.0842; feature_fraction=0.999; num_leaves=1017; min_data_in_leaf=1547 : y = 0.928 : 131.6 secs : infill_ei
#
# Tue Nov 04 08:24:38 AM 2025 AUC 0.907251198202392
#
# [mbo] 41: num_iterations=40; learning_rate=0.023; feature_fraction=1; num_leaves=845; min_data_in_leaf=4551 : y = 0.907 : 6.6 secs : infill_ei
#
# Tue Nov 04 08:24:44 AM 2025 AUC 0.910399769439075
#
# [mbo] 42: num_iterations=8; learning_rate=0.0733; feature_fraction=0.628; num_leaves=2043; min_data_in_leaf=1553 : y = 0.91 : 5.2 secs : infill_ei
#
# Tue Nov 04 08:28:50 AM 2025 AUC 0.927398902257394
#
# [mbo] 43: num_iterations=990; learning_rate=0.0897; feature_fraction=0.994; num_leaves=487; min_data_in_leaf=1284 : y = 0.927 : 244.6 secs : infill_ei
#
# Tue Nov 04 08:31:28 AM 2025 AUC 0.928669401499117
#
# [mbo] 44: num_iterations=475; learning_rate=0.0319; feature_fraction=0.852; num_leaves=1805; min_data_in_leaf=530 : y = 0.929 : 158.1 secs : infill_ei
#
# Saved the current state after iteration 45 in the file bayesiana.RDATA.
#
# Tue Nov 04 08:34:40 AM 2025 AUC 0.929162918992963
#
# [mbo] 45: num_iterations=738; learning_rate=0.0206; feature_fraction=0.31; num_leaves=835; min_data_in_leaf=1495 : y = 0.929 : 190.9 secs : infill_ei
#
# Tue Nov 04 08:40:57 AM 2025 AUC 0.927228000229939
#
# [mbo] 46: num_iterations=1612; learning_rate=0.0129; feature_fraction=0.42; num_leaves=8; min_data_in_leaf=4339 : y = 0.927 : 376.6 secs : infill_ei
#
# Tue Nov 04 08:47:37 AM 2025 AUC 0.930809199716008
#
# [mbo] 47: num_iterations=1593; learning_rate=0.0104; feature_fraction=0.377; num_leaves=29; min_data_in_leaf=464 : y = 0.931 : 398.9 secs : infill_ei
#
# Saved the current state after iteration 48 in the file bayesiana.RDATA.
#
# Tue Nov 04 08:54:27 AM 2025 AUC 0.928531090222934
#
# [mbo] 48: num_iterations=1791; learning_rate=0.0186; feature_fraction=0.407; num_leaves=9; min_data_in_leaf=1251 : y = 0.929 : 409.0 secs : infill_ei
#
# Tue Nov 04 08:57:29 AM 2025 AUC 0.927331023614821
#
# [mbo] 49: num_iterations=792; learning_rate=0.087; feature_fraction=1; num_leaves=75; min_data_in_leaf=1698 : y = 0.927 : 181.7 secs : infill_ei
#
# Tue Nov 04 09:00:49 AM 2025 AUC 0.93001540220878
#
# [mbo] 50: num_iterations=598; learning_rate=0.024; feature_fraction=0.602; num_leaves=853; min_data_in_leaf=612 : y = 0.93 : 199.1 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "num_iterations"   "learning_rate"    "feature_fraction" "num_leaves"
#  [5] "min_data_in_leaf" "y"                "dob"              "eol"
#  [9] "error.message"    "exec.time"        "ei"               "error.model"
# [13] "train.time"       "prop.type"        "propose.time"     "se"
# [17] "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    num_iterations learning_rate feature_fraction num_leaves min_data_in_leaf
#             <int>         <num>            <num>      <int>            <int>
# 1:           1638    0.01906673        0.3402496         53              631
# [1] 0.9317116

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 999961
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1638
#
# $learning_rate
# [1] 0.01906673
#
# $feature_fraction
# [1] 0.3402496
#
# $num_leaves
# [1] 53
#
# $min_data_in_leaf
# [1] 631

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}
# Out:
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Nov 04 09:09:24 AM 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-05**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-05**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-05**  en caso de ser necesario.
