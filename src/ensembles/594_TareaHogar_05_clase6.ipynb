# %% [markdown]
# <a href="https://colab.research.google.com/github/patriciasandagorda/labo2025v/blob/main/src/ensembles/594_TareaHogar_05_clase6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea para el Hogar 05

# %% [markdown]
# Esta Tarea para el Hogar 05 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el miercoles 03 de septiembre

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/austral2025-af91/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Nov 04 02:04:33 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660468 35.3 1454468    77.7 1438476  76.9
# Vcells 1226772  9.4 8388608    64.0 1975128  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- "5940_3"
PARAM$semilla_primigenia <- 999961

# %%
PARAM$kaggle$competencia <- "labo-i-2025-virtual-analista-sr"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1000,
  learning_rate= 0.03,
  feature_fraction= 0.5,
  num_leaves= 100,
  min_data_in_leaf= 300
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_iterations", lower= 8L, upper= 2048L),
  makeNumericParam("learning_rate", lower= 0.01, upper= 0.3),
  makeNumericParam("feature_fraction", lower= 0.1, upper= 1.0),
  makeIntegerParam("num_leaves", lower= 8L, upper= 2048L),
  makeIntegerParam("min_data_in_leaf", lower= 1L, upper= 8000L)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 50 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83435
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Tue Nov 04 02:22:43 PM 2025 AUC 0.926840065609736
#
# Tue Nov 04 02:25:54 PM 2025 AUC 0.9230480711174
#
# Tue Nov 04 02:30:04 PM 2025 AUC 0.925529649001866
#
# Tue Nov 04 02:32:24 PM 2025 AUC 0.92614310570443
#
# Tue Nov 04 02:32:40 PM 2025 AUC 0.926711633262798
#
# Tue Nov 04 02:36:57 PM 2025 AUC 0.923826192106459
#
# Tue Nov 04 02:41:25 PM 2025 AUC 0.923909306437032
#
# Tue Nov 04 02:43:14 PM 2025 AUC 0.923707935119915
#
# Tue Nov 04 02:44:37 PM 2025 AUC 0.924812060295485
#
# Tue Nov 04 02:45:32 PM 2025 AUC 0.923681071006952
#
# Tue Nov 04 02:49:27 PM 2025 AUC 0.926710426454201
#
# Tue Nov 04 02:50:37 PM 2025 AUC 0.92401294803416
#
# Tue Nov 04 02:52:37 PM 2025 AUC 0.918829943830197
#
# Tue Nov 04 02:57:22 PM 2025 AUC 0.92839297565181
#
# Tue Nov 04 02:57:36 PM 2025 AUC 0.908609912283744
#
# Tue Nov 04 03:02:08 PM 2025 AUC 0.925871642685418
#
# Tue Nov 04 03:07:37 PM 2025 AUC 0.922674613762548
#
# Tue Nov 04 03:12:12 PM 2025 AUC 0.926331192366254
#
# Tue Nov 04 03:14:39 PM 2025 AUC 0.92867429401663
#
# Tue Nov 04 03:15:41 PM 2025 AUC 0.924212906161167
#
# [mbo] 0: num_iterations=1690; learning_rate=0.105; feature_fraction=0.219; num_leaves=1572; min_data_in_leaf=2514 : y = 0.927 : 285.2 secs : initdesign
#
# [mbo] 0: num_iterations=940; learning_rate=0.255; feature_fraction=0.605; num_leaves=256; min_data_in_leaf=1376 : y = 0.923 : 190.6 secs : initdesign
#
# [mbo] 0: num_iterations=1040; learning_rate=0.192; feature_fraction=0.493; num_leaves=683; min_data_in_leaf=1651 : y = 0.926 : 249.9 secs : initdesign
#
# [mbo] 0: num_iterations=1261; learning_rate=0.0957; feature_fraction=0.811; num_leaves=1007; min_data_in_leaf=5985 : y = 0.926 : 140.8 secs : initdesign
#
# [mbo] 0: num_iterations=121; learning_rate=0.157; feature_fraction=0.901; num_leaves=1686; min_data_in_leaf=4977 : y = 0.927 : 15.9 secs : initdesign
#
# [mbo] 0: num_iterations=1547; learning_rate=0.147; feature_fraction=0.31; num_leaves=360; min_data_in_leaf=7705 : y = 0.924 : 256.7 secs : initdesign
#
# [mbo] 0: num_iterations=1912; learning_rate=0.27; feature_fraction=0.864; num_leaves=1851; min_data_in_leaf=2959 : y = 0.924 : 268.2 secs : initdesign
#
# [mbo] 0: num_iterations=839; learning_rate=0.181; feature_fraction=0.139; num_leaves=779; min_data_in_leaf=6180 : y = 0.924 : 108.9 secs : initdesign
#
# [mbo] 0: num_iterations=658; learning_rate=0.273; feature_fraction=0.962; num_leaves=1138; min_data_in_leaf=4106 : y = 0.925 : 82.7 secs : initdesign
#
# [mbo] 0: num_iterations=267; learning_rate=0.241; feature_fraction=0.451; num_leaves=1460; min_data_in_leaf=5236 : y = 0.924 : 55.2 secs : initdesign
#
# [mbo] 0: num_iterations=1774; learning_rate=0.133; feature_fraction=0.644; num_leaves=430; min_data_in_leaf=3836 : y = 0.927 : 235.4 secs : initdesign
#
# [mbo] 0: num_iterations=430; learning_rate=0.0307; feature_fraction=0.586; num_leaves=560; min_data_in_leaf=7177 : y = 0.924 : 70.0 secs : initdesign
#
# [mbo] 0: num_iterations=320; learning_rate=0.225; feature_fraction=0.715; num_leaves=1299; min_data_in_leaf=56 : y = 0.919 : 119.3 secs : initdesign
#
# [mbo] 0: num_iterations=1203; learning_rate=0.0715; feature_fraction=0.366; num_leaves=912; min_data_in_leaf=788 : y = 0.928 : 285.2 secs : initdesign
#
# [mbo] 0: num_iterations=78; learning_rate=0.0115; feature_fraction=0.246; num_leaves=1351; min_data_in_leaf=3572 : y = 0.909 : 14.2 secs : initdesign
#
# [mbo] 0: num_iterations=1360; learning_rate=0.12; feature_fraction=0.547; num_leaves=1743; min_data_in_leaf=6590 : y = 0.926 : 272.1 secs : initdesign
#
# [mbo] 0: num_iterations=1520; learning_rate=0.286; feature_fraction=0.413; num_leaves=1127; min_data_in_leaf=2241 : y = 0.923 : 329.0 secs : initdesign
#
# [mbo] 0: num_iterations=2006; learning_rate=0.0505; feature_fraction=0.149; num_leaves=37; min_data_in_leaf=4457 : y = 0.926 : 275.2 secs : initdesign
#
# [mbo] 0: num_iterations=791; learning_rate=0.0636; feature_fraction=0.944; num_leaves=1977; min_data_in_leaf=1173 : y = 0.929 : 147.1 secs : initdesign
#
# [mbo] 0: num_iterations=575; learning_rate=0.202; feature_fraction=0.753; num_leaves=158; min_data_in_leaf=7348 : y = 0.924 : 61.6 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Tue Nov 04 03:20:20 PM 2025 AUC 0.928782676100714
#
# [mbo] 1: num_iterations=1300; learning_rate=0.0818; feature_fraction=1; num_leaves=1922; min_data_in_leaf=841 : y = 0.929 : 278.2 secs : infill_ei
#
# Tue Nov 04 03:23:35 PM 2025 AUC 0.927232807579585
#
# [mbo] 2: num_iterations=1098; learning_rate=0.0921; feature_fraction=0.996; num_leaves=595; min_data_in_leaf=1381 : y = 0.927 : 194.4 secs : infill_ei
#
# Tue Nov 04 03:29:51 PM 2025 AUC 0.927554586301892
#
# [mbo] 3: num_iterations=1969; learning_rate=0.0649; feature_fraction=0.888; num_leaves=1729; min_data_in_leaf=1146 : y = 0.928 : 375.5 secs : infill_ei
#
# Saved the current state after iteration 4 in the file bayesiana.RDATA.
#
# Tue Nov 04 03:35:23 PM 2025 AUC 0.921784185151769
#
# [mbo] 4: num_iterations=1058; learning_rate=0.0685; feature_fraction=0.915; num_leaves=1880; min_data_in_leaf=4 : y = 0.922 : 332.1 secs : infill_ei
#
# Tue Nov 04 03:39:45 PM 2025 AUC 0.926998774660281
#
# [mbo] 5: num_iterations=1228; learning_rate=0.0932; feature_fraction=0.316; num_leaves=2020; min_data_in_leaf=1084 : y = 0.927 : 261.2 secs : infill_ei
#
# Tue Nov 04 03:42:41 PM 2025 AUC 0.927410631418588
#
# [mbo] 6: num_iterations=854; learning_rate=0.0737; feature_fraction=0.979; num_leaves=1286; min_data_in_leaf=940 : y = 0.927 : 175.2 secs : infill_ei
#
# Saved the current state after iteration 7 in the file bayesiana.RDATA.
#
# Tue Nov 04 03:46:43 PM 2025 AUC 0.927898353878375
#
# [mbo] 7: num_iterations=1282; learning_rate=0.0124; feature_fraction=0.912; num_leaves=1943; min_data_in_leaf=1109 : y = 0.928 : 242.0 secs : infill_ei
#
# Tue Nov 04 03:50:50 PM 2025 AUC 0.926280890972623
#
# [mbo] 8: num_iterations=2016; learning_rate=0.154; feature_fraction=0.923; num_leaves=360; min_data_in_leaf=4527 : y = 0.926 : 246.5 secs : infill_ei
#
# Tue Nov 04 03:53:19 PM 2025 AUC 0.928832563706709
#
# [mbo] 9: num_iterations=876; learning_rate=0.0627; feature_fraction=0.999; num_leaves=2029; min_data_in_leaf=1654 : y = 0.929 : 148.3 secs : infill_ei
#
# Saved the current state after iteration 10 in the file bayesiana.RDATA.
#
# Tue Nov 04 04:00:23 PM 2025 AUC 0.928128256051797
#
# [mbo] 10: num_iterations=1786; learning_rate=0.0418; feature_fraction=0.617; num_leaves=2044; min_data_in_leaf=717 : y = 0.928 : 423.4 secs : infill_ei
#
# Tue Nov 04 04:04:43 PM 2025 AUC 0.927608170527166
#
# [mbo] 11: num_iterations=1618; learning_rate=0.102; feature_fraction=0.996; num_leaves=1940; min_data_in_leaf=2002 : y = 0.928 : 259.9 secs : infill_ei
#
# Saved the current state after iteration 12 in the file bayesiana.RDATA.
#
# Tue Nov 04 04:11:27 PM 2025 AUC 0.92840783003966
#
# [mbo] 12: num_iterations=1722; learning_rate=0.0674; feature_fraction=0.372; num_leaves=309; min_data_in_leaf=826 : y = 0.928 : 403.0 secs : infill_ei
#
# Tue Nov 04 04:15:59 PM 2025 AUC 0.924503826805209
#
# [mbo] 13: num_iterations=1959; learning_rate=0.126; feature_fraction=0.127; num_leaves=47; min_data_in_leaf=2436 : y = 0.925 : 271.4 secs : infill_ei
#
# Saved the current state after iteration 14 in the file bayesiana.RDATA.
#
# Tue Nov 04 04:21:30 PM 2025 AUC 0.927654876581672
#
# [mbo] 14: num_iterations=1552; learning_rate=0.0607; feature_fraction=0.751; num_leaves=1126; min_data_in_leaf=792 : y = 0.928 : 331.0 secs : infill_ei
#
# Tue Nov 04 04:24:07 PM 2025 AUC 0.926436641848439
#
# [mbo] 15: num_iterations=1056; learning_rate=0.018; feature_fraction=0.105; num_leaves=472; min_data_in_leaf=781 : y = 0.926 : 156.8 secs : infill_ei
#
# Tue Nov 04 04:27:11 PM 2025 AUC 0.926736227299336
#
# [mbo] 16: num_iterations=1537; learning_rate=0.121; feature_fraction=0.783; num_leaves=2045; min_data_in_leaf=4983 : y = 0.927 : 183.4 secs : infill_ei
#
# Saved the current state after iteration 17 in the file bayesiana.RDATA.
#
# Tue Nov 04 04:33:59 PM 2025 AUC 0.9275176943986
#
# [mbo] 17: num_iterations=1672; learning_rate=0.0672; feature_fraction=0.543; num_leaves=1933; min_data_in_leaf=1630 : y = 0.928 : 406.7 secs : infill_ei
#
# Tue Nov 04 04:40:52 PM 2025 AUC 0.928255042756119
#
# [mbo] 18: num_iterations=2046; learning_rate=0.0658; feature_fraction=0.231; num_leaves=1036; min_data_in_leaf=672 : y = 0.928 : 413.2 secs : infill_ei
#
# Saved the current state after iteration 19 in the file bayesiana.RDATA.
#
# Tue Nov 04 04:45:06 PM 2025 AUC 0.925461679137213
#
# [mbo] 19: num_iterations=1986; learning_rate=0.0986; feature_fraction=0.131; num_leaves=13; min_data_in_leaf=5051 : y = 0.925 : 253.4 secs : infill_ei
#
# Tue Nov 04 04:46:43 PM 2025 AUC 0.92772072659385
#
# [mbo] 20: num_iterations=541; learning_rate=0.0807; feature_fraction=0.994; num_leaves=2042; min_data_in_leaf=1467 : y = 0.928 : 96.0 secs : infill_ei
#
# Tue Nov 04 04:50:14 PM 2025 AUC 0.926388857315601
#
# [mbo] 21: num_iterations=1128; learning_rate=0.0933; feature_fraction=0.999; num_leaves=2042; min_data_in_leaf=1261 : y = 0.926 : 210.7 secs : infill_ei
#
# Tue Nov 04 04:53:28 PM 2025 AUC 0.926938610049173
#
# [mbo] 22: num_iterations=1353; learning_rate=0.0106; feature_fraction=1; num_leaves=568; min_data_in_leaf=2838 : y = 0.927 : 192.9 secs : infill_ei
#
# Saved the current state after iteration 23 in the file bayesiana.RDATA.
#
# Tue Nov 04 04:54:34 PM 2025 AUC 0.927151667377852
#
# [mbo] 23: num_iterations=391; learning_rate=0.0507; feature_fraction=0.976; num_leaves=1643; min_data_in_leaf=1752 : y = 0.927 : 65.9 secs : infill_ei
#
# Tue Nov 04 04:57:53 PM 2025 AUC 0.928185896625234
#
# [mbo] 24: num_iterations=1278; learning_rate=0.0525; feature_fraction=0.836; num_leaves=515; min_data_in_leaf=1992 : y = 0.928 : 198.8 secs : infill_ei
#
# Tue Nov 04 04:59:46 PM 2025 AUC 0.927445659397054
#
# [mbo] 25: num_iterations=753; learning_rate=0.0431; feature_fraction=1; num_leaves=1825; min_data_in_leaf=2385 : y = 0.927 : 112.4 secs : infill_ei
#
# Tue Nov 04 05:04:04 PM 2025 AUC 0.926991374574189
#
# [mbo] 26: num_iterations=1760; learning_rate=0.07; feature_fraction=0.99; num_leaves=777; min_data_in_leaf=2588 : y = 0.927 : 256.8 secs : infill_ei
#
# Saved the current state after iteration 27 in the file bayesiana.RDATA.
#
# Tue Nov 04 05:06:12 PM 2025 AUC 0.927739244904646
#
# [mbo] 27: num_iterations=752; learning_rate=0.0315; feature_fraction=0.975; num_leaves=1567; min_data_in_leaf=1640 : y = 0.928 : 127.3 secs : infill_ei
#
# Tue Nov 04 05:09:45 PM 2025 AUC 0.927607108914538
#
# [mbo] 28: num_iterations=1368; learning_rate=0.0532; feature_fraction=0.998; num_leaves=2018; min_data_in_leaf=2172 : y = 0.928 : 212.8 secs : infill_ei
#
# Tue Nov 04 05:11:49 PM 2025 AUC 0.924769204646955
#
# [mbo] 29: num_iterations=760; learning_rate=0.0629; feature_fraction=0.13; num_leaves=1988; min_data_in_leaf=834 : y = 0.925 : 123.9 secs : infill_ei
#
# Tue Nov 04 05:14:06 PM 2025 AUC 0.928438384542438
#
# [mbo] 30: num_iterations=855; learning_rate=0.0747; feature_fraction=0.999; num_leaves=132; min_data_in_leaf=1970 : y = 0.928 : 135.9 secs : infill_ei
#
# Saved the current state after iteration 31 in the file bayesiana.RDATA.
#
# Tue Nov 04 05:18:17 PM 2025 AUC 0.929583291940621
#
# [mbo] 31: num_iterations=1315; learning_rate=0.0653; feature_fraction=0.382; num_leaves=18; min_data_in_leaf=1049 : y = 0.93 : 250.9 secs : infill_ei
#
# Tue Nov 04 05:18:56 PM 2025 AUC 0.92513376966398
#
# [mbo] 32: num_iterations=323; learning_rate=0.179; feature_fraction=1; num_leaves=2048; min_data_in_leaf=6293 : y = 0.925 : 38.3 secs : infill_ei
#
# Tue Nov 04 05:26:14 PM 2025 AUC 0.927760716043874
#
# [mbo] 33: num_iterations=2047; learning_rate=0.0102; feature_fraction=0.532; num_leaves=2046; min_data_in_leaf=5213 : y = 0.928 : 437.2 secs : infill_ei
#
# Saved the current state after iteration 34 in the file bayesiana.RDATA.
#
# Tue Nov 04 05:30:18 PM 2025 AUC 0.927620133186352
#
# [mbo] 34: num_iterations=1947; learning_rate=0.0458; feature_fraction=0.959; num_leaves=2048; min_data_in_leaf=4097 : y = 0.928 : 243.1 secs : infill_ei
#
# Tue Nov 04 05:36:33 PM 2025 AUC 0.925500634276595
#
# [mbo] 35: num_iterations=1865; learning_rate=0.109; feature_fraction=0.226; num_leaves=2048; min_data_in_leaf=712 : y = 0.926 : 374.6 secs : infill_ei
#
# Saved the current state after iteration 36 in the file bayesiana.RDATA.
#
# Tue Nov 04 05:41:54 PM 2025 AUC 0.927264244995491
#
# [mbo] 36: num_iterations=2047; learning_rate=0.0102; feature_fraction=0.13; num_leaves=252; min_data_in_leaf=928 : y = 0.927 : 319.9 secs : infill_ei
#
# Tue Nov 04 05:46:03 PM 2025 AUC 0.928543113024047
#
# [mbo] 37: num_iterations=1148; learning_rate=0.0673; feature_fraction=0.385; num_leaves=57; min_data_in_leaf=1493 : y = 0.929 : 248.8 secs : infill_ei
#
# Tue Nov 04 05:51:52 PM 2025 AUC 0.927883839664694
#
# [mbo] 38: num_iterations=1329; learning_rate=0.0782; feature_fraction=0.522; num_leaves=521; min_data_in_leaf=1120 : y = 0.928 : 348.1 secs : infill_ei
#
# Saved the current state after iteration 39 in the file bayesiana.RDATA.
#
# Tue Nov 04 05:55:50 PM 2025 AUC 0.926974900109813
#
# [mbo] 39: num_iterations=2002; learning_rate=0.0103; feature_fraction=0.989; num_leaves=999; min_data_in_leaf=4880 : y = 0.927 : 237.6 secs : infill_ei
#
# Tue Nov 04 05:59:19 PM 2025 AUC 0.92958908206994
#
# [mbo] 40: num_iterations=1318; learning_rate=0.059; feature_fraction=0.296; num_leaves=8; min_data_in_leaf=860 : y = 0.93 : 208.4 secs : infill_ei
#
# Tue Nov 04 06:01:27 PM 2025 AUC 0.926265373170804
#
# [mbo] 41: num_iterations=1274; learning_rate=0.142; feature_fraction=0.999; num_leaves=11; min_data_in_leaf=1353 : y = 0.926 : 127.1 secs : infill_ei
#
# Tue Nov 04 06:06:29 PM 2025 AUC 0.928418461458222
#
# [mbo] 42: num_iterations=1379; learning_rate=0.041; feature_fraction=0.329; num_leaves=1007; min_data_in_leaf=1006 : y = 0.928 : 301.9 secs : infill_ei
#
# Saved the current state after iteration 43 in the file bayesiana.RDATA.
#
# Tue Nov 04 06:10:27 PM 2025 AUC 0.925751849316633
#
# [mbo] 43: num_iterations=2047; learning_rate=0.0275; feature_fraction=1; num_leaves=2048; min_data_in_leaf=5898 : y = 0.926 : 237.4 secs : infill_ei
#
# Tue Nov 04 06:17:52 PM 2025 AUC 0.928014857950536
#
# [mbo] 44: num_iterations=2048; learning_rate=0.0872; feature_fraction=0.497; num_leaves=2040; min_data_in_leaf=4423 : y = 0.928 : 443.8 secs : infill_ei
#
# Saved the current state after iteration 45 in the file bayesiana.RDATA.
#
# Tue Nov 04 06:27:25 PM 2025 AUC 0.930706451405121
#
# [mbo] 45: num_iterations=2048; learning_rate=0.0101; feature_fraction=0.454; num_leaves=1024; min_data_in_leaf=559 : y = 0.931 : 572.5 secs : infill_ei
#
# Tue Nov 04 06:41:21 PM 2025 AUC 0.928422530380208
#
# [mbo] 46: num_iterations=2048; learning_rate=0.0147; feature_fraction=0.501; num_leaves=579; min_data_in_leaf=4 : y = 0.928 : 835.7 secs : infill_ei
#
# Saved the current state after iteration 47 in the file bayesiana.RDATA.
#
# Tue Nov 04 06:49:46 PM 2025 AUC 0.930155926184593
#
# [mbo] 47: num_iterations=2048; learning_rate=0.0103; feature_fraction=0.426; num_leaves=1116; min_data_in_leaf=972 : y = 0.93 : 503.9 secs : infill_ei
#
# Tue Nov 04 06:57:25 PM 2025 AUC 0.927366232122424
#
# [mbo] 48: num_iterations=2048; learning_rate=0.0104; feature_fraction=0.472; num_leaves=1994; min_data_in_leaf=2979 : y = 0.927 : 458.5 secs : infill_ei
#
# Saved the current state after iteration 49 in the file bayesiana.RDATA.
#
# Tue Nov 04 07:03:01 PM 2025 AUC 0.926758944525282
#
# [mbo] 49: num_iterations=1697; learning_rate=0.0102; feature_fraction=0.404; num_leaves=1154; min_data_in_leaf=4574 : y = 0.927 : 335.1 secs : infill_ei
#
# Tue Nov 04 07:09:39 PM 2025 AUC 0.929090645900063
#
# [mbo] 50: num_iterations=1724; learning_rate=0.0104; feature_fraction=0.999; num_leaves=2028; min_data_in_leaf=695 : y = 0.929 : 396.8 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "num_iterations"   "learning_rate"    "feature_fraction" "num_leaves"
#  [5] "min_data_in_leaf" "y"                "dob"              "eol"
#  [9] "error.message"    "exec.time"        "ei"               "error.model"
# [13] "train.time"       "prop.type"        "propose.time"     "se"
# [17] "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    num_iterations learning_rate feature_fraction num_leaves min_data_in_leaf
#             <int>         <num>            <num>      <int>            <int>
# 1:           2048    0.01008553         0.453641       1024              559
# [1] 0.9307065

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 999961
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 2048
#
# $learning_rate
# [1] 0.01008553
#
# $feature_fraction
# [1] 0.453641
#
# $num_leaves
# [1] 1024
#
# $min_data_in_leaf
# [1] 559

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}
# Out:
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Nov 04 07:20:42 PM 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-05**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-05**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-05**  en caso de ser necesario.
