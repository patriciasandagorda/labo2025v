# %% [markdown]
# <a href="https://colab.research.google.com/github/patriciasandagorda/labo2025v/blob/main/src/workflows/910_WorkFlow_01_junior.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 9 WorkFlow Analista Jr

# %% [markdown]
# ### 9.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán
# <br>El Analista Jr corre sus scripts en la virtual manchine **desktop-jr** que tiene estas características
#
#
# *   Normal, paga tarifa completa, nunca es apagada por Google
# *   reside en el datacenter de Sao Paulo, Brasil
# *   64 GB de memoria RAM
# *   8 vCPU

# %% [markdown]
# ## 9.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sun Nov 30 22:05:03 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  659629 35.3 1450814    77.5 1450814  77.5
# Vcells 1226357  9.4 8388608    64.0 1975148  15.1

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 999959

PARAM$experimento <- "9100_competencia_V5_999959"
PARAM$dataset <- "analistajr_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 9.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 9.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 9.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
AsignarNA_campomeses <- function(pcampo, pmeses) {

  if( pcampo %in% colnames( dataset ) ) {

    dataset[ foto_mes %in% pmeses, paste0(pcampo) := NA ]
  }
}

# %%
Corregir_atributo <- function(pcampo, pmeses, pmetodo)
{
  # si el campo no existe en el dataset, Afuera !
  if( !(pcampo %in% colnames( dataset )) )
    return( 1 )

    AsignarNA_campomeses(pcampo, pmeses)

  return( 0 )
}

# %%
Corregir_Rotas <- function(dataset, pmetodo) {
  gc(verbose= FALSE)
  cat( "inicio Corregir_Rotas()\n")
  # acomodo los errores del dataset

  Corregir_atributo("active_quarter", c(202006), pmetodo) # 1
  Corregir_atributo("internet", c(202006), pmetodo) # 2

  Corregir_atributo("mrentabilidad", c(201905, 201910, 202006), pmetodo) # 3
  Corregir_atributo("mrentabilidad_annual", c(201905, 201910, 202006), pmetodo) # 4

  Corregir_atributo("mcomisiones", c(201905, 201910, 202006), pmetodo) # 5

  Corregir_atributo("mactivos_margen", c(201905, 201910, 202006), pmetodo) # 6
  Corregir_atributo("mpasivos_margen", c(201905, 201910, 202006), pmetodo) # 7

  Corregir_atributo("mcuentas_saldo", c(202006), pmetodo) # 8

  Corregir_atributo("ctarjeta_debito_transacciones", c(202006), pmetodo) # 9

  Corregir_atributo("mautoservicio", c(202006), pmetodo) # 10

  Corregir_atributo("ctarjeta_visa_transacciones", c(202006), pmetodo) # 11
  Corregir_atributo("mtarjeta_visa_consumo", c(202006), pmetodo) # 12

  Corregir_atributo("ctarjeta_master_transacciones", c(202006), pmetodo) # 13
  Corregir_atributo("mtarjeta_master_consumo", c(202006), pmetodo) # 14

  Corregir_atributo("ctarjeta_visa_debitos_automaticos", c(201904), pmetodo) # 15
  Corregir_atributo("mttarjeta_visa_debitos_automaticos", c(201904), pmetodo) # 16

  Corregir_atributo("ccajeros_propios_descuentos",
    c(201910, 202002, 202006, 202009, 202010, 202102), pmetodo) # 17

  Corregir_atributo("mcajeros_propios_descuentos",
    c(201910, 202002, 202006, 202009, 202010, 202102), pmetodo) # 18

  Corregir_atributo("ctarjeta_visa_descuentos",
    c(201910, 202002, 202006, 202009, 202010, 202102), pmetodo) # 19

  Corregir_atributo("mtarjeta_visa_descuentos",
    c(201910, 202002, 202006, 202009, 202010, 202102), pmetodo) # 20

  Corregir_atributo("ctarjeta_master_descuentos",
    c(201910, 202002, 202006, 202009, 202010, 202102), pmetodo) # 21

  Corregir_atributo("mtarjeta_master_descuentos",
    c(201910, 202002, 202006, 202009, 202010, 202102), pmetodo) # 22

  Corregir_atributo("ccomisiones_otras", c(201905, 201910, 202006), pmetodo) # 23
  Corregir_atributo("mcomisiones_otras", c(201905, 201910, 202006), pmetodo) # 24

  Corregir_atributo("cextraccion_autoservicio", c(202006), pmetodo) # 25
  Corregir_atributo("mextraccion_autoservicio", c(202006), pmetodo) # 26

  Corregir_atributo("ccheques_depositados", c(202006), pmetodo) # 27
  Corregir_atributo("mcheques_depositados", c(202006), pmetodo) # 28
  Corregir_atributo("ccheques_emitidos", c(202006), pmetodo) # 29
  Corregir_atributo("mcheques_emitidos", c(202006), pmetodo) # 30
  Corregir_atributo("ccheques_depositados_rechazados", c(202006), pmetodo) # 31
  Corregir_atributo("mcheques_depositados_rechazados", c(202006), pmetodo) # 32
  Corregir_atributo("ccheques_emitidos_rechazados", c(202006), pmetodo) # 33
  Corregir_atributo("mcheques_emitidos_rechazados", c(202006), pmetodo) # 34

  Corregir_atributo("tcallcenter", c(202006), pmetodo) # 35
  Corregir_atributo("ccallcenter_transacciones", c(202006), pmetodo) # 36

  Corregir_atributo("thomebanking", c(202006), pmetodo) # 37
  Corregir_atributo("chomebanking_transacciones", c(201910, 202006), pmetodo) # 38

  Corregir_atributo("ccajas_transacciones", c(202006), pmetodo) # 39
  Corregir_atributo("ccajas_consultas", c(202006), pmetodo) # 40

  Corregir_atributo("ccajas_depositos", c(202006, 202105), pmetodo) # 41

  Corregir_atributo("ccajas_extracciones", c(202006), pmetodo) # 41
  Corregir_atributo("ccajas_otras", c(202006), pmetodo) # 43

  Corregir_atributo("catm_trx", c(202006), pmetodo) # 44
  Corregir_atributo("matm", c(202006), pmetodo) # 45
  Corregir_atributo("catm_trx_other", c(202006), pmetodo) # 46
  Corregir_atributo("matm_other", c(202006), pmetodo) # 47

  cat( "fin Corregir_rotas()\n")
}

# %%
# resuelvo el Catastrophe Analysis

setorder( dataset, numero_de_cliente, foto_mes )

PARAM$CA$metodo= "MachineLearning"

if( PARAM$CA$metodo %in% c("MachineLearning") )
  Corregir_Rotas(dataset, PARAM$CA$metodo)
# Out:
# inicio Corregir_Rotas()
# fin Corregir_rotas()

# %% [markdown]
# #### 9.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, ajustando por algunos indices financieros

# %%
# El cero se transforma en cero
# los positivos se rankean por su lado
# los negativos se rankean por su lado

drift_rank_cero_fijo <- function(campos_drift) {

  cat( "inicio drift_rank_cero_fijo()\n")
  for (campo in campos_drift)
  {
    cat(campo, " ")
    dataset[get(campo) == 0, paste0(campo, "_rank") := 0]
    dataset[get(campo) > 0, paste0(campo, "_rank") :=
      frank(get(campo), ties.method = "random") / .N, by = list(foto_mes)]

    dataset[get(campo) < 0, paste0(campo, "_rank") :=
      -frank(-get(campo), ties.method = "random") / .N, by = list(foto_mes)]
    dataset[, (campo) := NULL]
  }
  cat("\n")
  cat( "fin drift_rank_cero_fijo()\n")
}

# %%
# por como armé los nombres de campos,
#  estos son los campos que expresan variables monetarias
campos_monetarios <- colnames(dataset)
campos_monetarios <- campos_monetarios[campos_monetarios %like%
  "^(m|Visa_m|Master_m|vm_m)"]

campos_monetarios
# Out:
#  [1] "mrentabilidad"                      "mrentabilidad_annual"
#  [3] "mcomisiones"                        "mactivos_margen"
#  [5] "mpasivos_margen"                    "mcuenta_corriente"
#  [7] "mcaja_ahorro"                       "mcuentas_saldo"
#  [9] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
# [11] "mprestamos_personales"              "mpayroll"
# [13] "mttarjeta_visa_debitos_automaticos" "mcomisiones_mantenimiento"
# [15] "mtransferencias_recibidas"          "Master_mfinanciacion_limite"
# [17] "Master_msaldototal"                 "Master_mlimitecompra"
# [19] "Master_mconsumototal"               "Master_mpagominimo"
# [21] "Visa_mfinanciacion_limite"          "Visa_msaldototal"
# [23] "Visa_mlimitecompra"                 "Visa_mconsumototal"
# [25] "Visa_mpagominimo"

# %%
# ejecuto el Data Drifting
setorder( dataset, numero_de_cliente, foto_mes )

drift_rank_cero_fijo(campos_monetarios)
# Out:
# inicio drift_rank_cero_fijo()
# mrentabilidad  mrentabilidad_annual  mcomisiones  mactivos_margen  mpasivos_margen  mcuenta_corriente  mcaja_ahorro  mcuentas_saldo  mtarjeta_visa_consumo  mtarjeta_master_consumo  mprestamos_personales  mpayroll  mttarjeta_visa_debitos_automaticos  mcomisiones_mantenimiento  mtransferencias_recibidas  Master_mfinanciacion_limite  Master_msaldototal  Master_mlimitecompra  Master_mconsumototal  Master_mpagominimo  Visa_mfinanciacion_limite  Visa_msaldototal  Visa_mlimitecompra  Visa_mconsumototal  Visa_mpagominimo
# fin drift_rank_cero_fijo()

# %%
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"
#  [2] "foto_mes"
#  [3] "internet"
#  [4] "cliente_edad"
#  [5] "cliente_antiguedad"
#  [6] "cproductos"
#  [7] "cdescubierto_preacordado"
#  [8] "ctarjeta_visa"
#  [9] "ctarjeta_visa_transacciones"
# [10] "ctarjeta_master"
# [11] "ctarjeta_master_transacciones"
# [12] "cprestamos_personales"
# [13] "cpayroll_trx"
# [14] "ccomisiones_mantenimiento"
# [15] "ccomisiones_otras"
# [16] "ccallcenter_transacciones"
# [17] "thomebanking"
# [18] "chomebanking_transacciones"
# [19] "ctrx_quarter"
# [20] "Master_status"
# [21] "Master_Fvencimiento"
# [22] "Master_fultimo_cierre"
# [23] "Master_fechaalta"
# [24] "Master_cconsumos"
# [25] "Visa_status"
# [26] "Visa_Fvencimiento"
# [27] "Visa_fultimo_cierre"
# [28] "Visa_fechaalta"
# [29] "Visa_cconsumos"
# [30] "clase_ternaria"
# [31] "mrentabilidad_rank"
# [32] "mrentabilidad_annual_rank"
# [33] "mcomisiones_rank"
# [34] "mactivos_margen_rank"
# [35] "mpasivos_margen_rank"
# [36] "mcuenta_corriente_rank"
# [37] "mcaja_ahorro_rank"
# [38] "mcuentas_saldo_rank"
# [39] "mtarjeta_visa_consumo_rank"
# [40] "mtarjeta_master_consumo_rank"
# [41] "mprestamos_personales_rank"
# [42] "mpayroll_rank"
# [43] "mttarjeta_visa_debitos_automaticos_rank"
# [44] "mcomisiones_mantenimiento_rank"
# [45] "mtransferencias_recibidas_rank"
# [46] "Master_mfinanciacion_limite_rank"
# [47] "Master_msaldototal_rank"
# [48] "Master_mlimitecompra_rank"
# [49] "Master_mconsumototal_rank"
# [50] "Master_mpagominimo_rank"
# [51] "Visa_mfinanciacion_limite_rank"
# [52] "Visa_msaldototal_rank"
# [53] "Visa_mlimitecompra_rank"
# [54] "Visa_mconsumototal_rank"
# [55] "Visa_mpagominimo_rank"

# %%
# se intenta corregir el data drifting utilizando algunos indices financieros

# %% [markdown]
# #### 9.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# %% [markdown]
# #### 9.3.1.4  FE_rf Feature Engineering de nuevas variables

# %%
if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")
# Out:
# Loading required package: lightgbm

# %%
AgregarVariables_IntraMes <- function(dataset) {
  cat( "inicio AgregarVariables_IntraMes()\n")
  gc(verbose= FALSE)
  # INICIO de la seccion donde se deben hacer cambios con variables nuevas

  # el mes 1,2, ..12
  if( atributos_presentes( c("foto_mes") ))
    dataset[, kmes := foto_mes %% 100]

  # creo un ctr_quarter que tenga en cuenta cuando
  # los clientes hace 3 menos meses que estan
  # ya que seria injusto considerar las transacciones medidas en menor tiempo
  if( atributos_presentes( c("ctrx_quarter") ))
    dataset[, ctrx_quarter_normalizado := as.numeric(ctrx_quarter) ]

  if( atributos_presentes( c("ctrx_quarter", "cliente_antiguedad") ))
    dataset[cliente_antiguedad == 1, ctrx_quarter_normalizado := ctrx_quarter * 5]

  if( atributos_presentes( c("ctrx_quarter", "cliente_antiguedad") ))
    dataset[cliente_antiguedad == 2, ctrx_quarter_normalizado := ctrx_quarter * 2]

  if( atributos_presentes( c("ctrx_quarter", "cliente_antiguedad") ))
    dataset[
      cliente_antiguedad == 3,
      ctrx_quarter_normalizado := ctrx_quarter * 1.2
    ]

   if(atributos_presentes(c("foto_mes")))
    dataset[,foto_mes_formato_fecha := as.Date(paste(substr(dataset$foto_mes,1,4),substr(dataset$foto_mes,5,6),"01",sep='-'))]

  #dataset$foto_mes_formato_fecha <<- as.Date(paste(substr(dataset$foto_mes,1,4),substr(dataset$foto_mes,5,6),"01",sep='-'))

  if(atributos_presentes(c("cantidad_total_transacciones"))){
   auxiliarmenos1 <- dataset[,list(numero_de_cliente,foto_mes_formato_fecha, cantidad_total_transacciones)]
   auxiliarmenos2 <- dataset[,list(numero_de_cliente,foto_mes_formato_fecha,cantidad_total_transacciones)]
   # auxiliarmenos1$foto_mes_formato_fecha <- as.Date(auxiliarmenos1$foto_mes_formato_fecha)
   # auxiliarmenos2$foto_mes_formato_fecha <- as.Date(auxiliarmenos2$foto_mes_formato_fecha)
   auxiliarmenos1$foto_mes_formato_fecha <- auxiliarmenos1$foto_mes_formato_fecha  %m-%  months(1)
   auxiliarmenos2$foto_mes_formato_fecha <- auxiliarmenos2$foto_mes_formato_fecha %m-% months(2)
   auxiliarmenos1$codigo <- paste(auxiliarmenos1$numero_de_cliente,auxiliarmenos1$foto_mes_formato_fecha,sep='-')
   auxiliarmenos2$codigo <- paste(auxiliarmenos2$numero_de_cliente,auxiliarmenos2$foto_mes_formato_fecha,sep='-')

   dataset[, codigo := paste(numero_de_cliente, foto_mes_formato_fecha, sep='-') ]

   dataset[ auxiliarmenos1,
            on = "codigo",
            transaccionesmenos1 := i.cantidad_total_transacciones ]

   dataset[ auxiliarmenos2,
            on = "codigo",
            transaccionesmenos2 := i.cantidad_total_transacciones ]

   dataset[, cantidad_total_transacciones_quarter := rowSums(cbind(cantidad_total_transacciones +
    transaccionesmenos1 + transaccionesmenos2),na.rm=T) ]

   dataset[, codigo := NULL ]
   dataset[, transaccionesmenos1 := NULL ]
   dataset[, transaccionesmenos2 := NULL ]
   dataset[, foto_mes_formato_fecha := NULL ]
   rm(auxiliarmenos1)
   rm(auxiliarmenos2)
  }

  if( atributos_presentes( c("cantidad_total_transacciones_quarter") ))
    dataset[, cantidad_total_transacciones_quarter_normalizado := cantidad_total_transacciones_quarter]

  if( atributos_presentes( c("cantidad_total_transacciones_quarter", "cliente_antiguedad") ))
    dataset[cliente_antiguedad == 1, cantidad_total_transacciones_quarter_normalizado := cantidad_total_transacciones_quarter * 5]

  if( atributos_presentes( c("cantidad_total_transacciones_quarter", "cliente_antiguedad") ))
    dataset[cliente_antiguedad == 2, cantidad_total_transacciones_quarter_normalizado := cantidad_total_transacciones_quarter * 2]

  if( atributos_presentes( c("cantidad_total_transacciones_quarter", "cliente_antiguedad") ))
    dataset[cliente_antiguedad == 3, cantidad_total_transacciones_quarter_normalizado := cantidad_total_transacciones_quarter * 1.2]

  # variable extraida de una tesis de maestria de Irlanda
  if( atributos_presentes( c("mpayroll", "cliente_edad") ))
    dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

  # se crean los nuevos campos para MasterCard  y Visa,
  #  teniendo en cuenta los NA's
  # varias formas de combinar Visa_status y Master_status
  if( atributos_presentes( c("Master_status", "Visa_status") ))
  {
    dataset[, vm_status01 := pmax(Master_status, Visa_status, na.rm = TRUE)]
    dataset[, vm_status02 := Master_status + Visa_status]

    dataset[, vm_status03 := pmax(
      ifelse(is.na(Master_status), 10, Master_status),
      ifelse(is.na(Visa_status), 10, Visa_status)
    )]

    dataset[, vm_status04 := ifelse(is.na(Master_status), 10, Master_status)
      + ifelse(is.na(Visa_status), 10, Visa_status)]

    dataset[, vm_status05 := ifelse(is.na(Master_status), 10, Master_status)
      + 100 * ifelse(is.na(Visa_status), 10, Visa_status)]

    dataset[, vm_status06 := ifelse(is.na(Visa_status),
      ifelse(is.na(Master_status), 10, Master_status),
      Visa_status
    )]

    dataset[, mv_status07 := ifelse(is.na(Master_status),
      ifelse(is.na(Visa_status), 10, Visa_status),
      Master_status
    )]
  }


  # combino MasterCard y Visa
  if( atributos_presentes( c("Master_mfinanciacion_limite", "Visa_mfinanciacion_limite") ))
    dataset[, vm_mfinanciacion_limite := rowSums(cbind(Master_mfinanciacion_limite, Visa_mfinanciacion_limite), na.rm = TRUE)]

  if( atributos_presentes( c("Master_Fvencimiento", "Visa_Fvencimiento") ))
    dataset[, vm_Fvencimiento := pmin(Master_Fvencimiento, Visa_Fvencimiento, na.rm = TRUE)]

  if( atributos_presentes( c("Master_Finiciomora", "Visa_Finiciomora") ))
    dataset[, vm_Finiciomora := pmin(Master_Finiciomora, Visa_Finiciomora, na.rm = TRUE)]

  if( atributos_presentes( c("Master_msaldototal", "Visa_msaldototal") ))
    dataset[, vm_msaldototal := rowSums(cbind(Master_msaldototal, Visa_msaldototal), na.rm = TRUE)]

  if( atributos_presentes( c("Master_msaldopesos", "Visa_msaldopesos") ))
    dataset[, vm_msaldopesos := rowSums(cbind(Master_msaldopesos, Visa_msaldopesos), na.rm = TRUE)]

  if( atributos_presentes( c("Master_msaldodolares", "Visa_msaldodolares") ))
    dataset[, vm_msaldodolares := rowSums(cbind(Master_msaldodolares, Visa_msaldodolares), na.rm = TRUE)]

  if( atributos_presentes( c("Master_mconsumospesos", "Visa_mconsumospesos") ))
    dataset[, vm_mconsumospesos := rowSums(cbind(Master_mconsumospesos, Visa_mconsumospesos), na.rm = TRUE)]

  if( atributos_presentes( c("Master_mconsumosdolares", "Visa_mconsumosdolares") ))
    dataset[, vm_mconsumosdolares := rowSums(cbind(Master_mconsumosdolares, Visa_mconsumosdolares), na.rm = TRUE)]

  if( atributos_presentes( c("Master_mlimitecompra", "Visa_mlimitecompra") ))
    dataset[, vm_mlimitecompra := rowSums(cbind(Master_mlimitecompra, Visa_mlimitecompra), na.rm = TRUE)]

  if( atributos_presentes( c("Master_madelantopesos", "Visa_madelantopesos") ))
    dataset[, vm_madelantopesos := rowSums(cbind(Master_madelantopesos, Visa_madelantopesos), na.rm = TRUE)]

  if( atributos_presentes( c("Master_madelantodolares", "Visa_madelantodolares") ))
    dataset[, vm_madelantodolares := rowSums(cbind(Master_madelantodolares, Visa_madelantodolares), na.rm = TRUE)]

  if( atributos_presentes( c("Master_fultimo_cierre", "Visa_fultimo_cierre") ))
    dataset[, vm_fultimo_cierre := pmax(Master_fultimo_cierre, Visa_fultimo_cierre, na.rm = TRUE)]

  if( atributos_presentes( c("Master_mpagado", "Visa_mpagado") ))
    dataset[, vm_mpagado := rowSums(cbind(Master_mpagado, Visa_mpagado), na.rm = TRUE)]

  if( atributos_presentes( c("Master_mpagospesos", "Visa_mpagospesos") ))
    dataset[, vm_mpagospesos := rowSums(cbind(Master_mpagospesos, Visa_mpagospesos), na.rm = TRUE)]

  if( atributos_presentes( c("Master_mpagosdolares", "Visa_mpagosdolares") ))
    dataset[, vm_mpagosdolares := rowSums(cbind(Master_mpagosdolares, Visa_mpagosdolares), na.rm = TRUE)]

  if( atributos_presentes( c("Master_fechaalta", "Visa_fechaalta") ))
    dataset[, vm_fechaalta := pmax(Master_fechaalta, Visa_fechaalta, na.rm = TRUE)]

  if( atributos_presentes( c("Master_mconsumototal", "Visa_mconsumototal") ))
    dataset[, vm_mconsumototal := rowSums(cbind(Master_mconsumototal, Visa_mconsumototal), na.rm = TRUE)]

  if( atributos_presentes( c("Master_cconsumos", "Visa_cconsumos") ))
    dataset[, vm_cconsumos := rowSums(cbind(Master_cconsumos, Visa_cconsumos), na.rm = TRUE)]

  if( atributos_presentes( c("Master_cadelantosefectivo", "Visa_cadelantosefectivo") ))
    dataset[, vm_cadelantosefectivo := rowSums(cbind(Master_cadelantosefectivo, Visa_cadelantosefectivo), na.rm = TRUE)]

  if( atributos_presentes( c("Master_mpagominimo", "Visa_mpagominimo") ))
    dataset[, vm_mpagominimo := rowSums(cbind(Master_mpagominimo, Visa_mpagominimo), na.rm = TRUE)]

  # a partir de aqui juego con la suma de Mastercard y Visa
  if( atributos_presentes( c("Master_mlimitecompra", "vm_mlimitecompra") ))
    dataset[, vmr_Master_mlimitecompra := Master_mlimitecompra / vm_mlimitecompra]

  if( atributos_presentes( c("Visa_mlimitecompra", "vm_mlimitecompra") ))
    dataset[, vmr_Visa_mlimitecompra := Visa_mlimitecompra / vm_mlimitecompra]

  if( atributos_presentes( c("vm_msaldototal", "vm_mlimitecompra") ))
    dataset[, vmr_msaldototal := vm_msaldototal / vm_mlimitecompra]

  if( atributos_presentes( c("vm_msaldopesos", "vm_mlimitecompra") ))
    dataset[, vmr_msaldopesos := vm_msaldopesos / vm_mlimitecompra]

  if( atributos_presentes( c("vm_msaldopesos", "vm_msaldototal") ))
    dataset[, vmr_msaldopesos2 := vm_msaldopesos / vm_msaldototal]

  if( atributos_presentes( c("vm_msaldodolares", "vm_mlimitecompra") ))
    dataset[, vmr_msaldodolares := vm_msaldodolares / vm_mlimitecompra]

  if( atributos_presentes( c("vm_msaldodolares", "vm_msaldototal") ))
    dataset[, vmr_msaldodolares2 := vm_msaldodolares / vm_msaldototal]

  if( atributos_presentes( c("vm_mconsumospesos", "vm_mlimitecompra") ))
    dataset[, vmr_mconsumospesos := vm_mconsumospesos / vm_mlimitecompra]

  if( atributos_presentes( c("vm_mconsumosdolares", "vm_mlimitecompra") ))
    dataset[, vmr_mconsumosdolares := vm_mconsumosdolares / vm_mlimitecompra]

  if( atributos_presentes( c("vm_madelantopesos", "vm_mlimitecompra") ))
    dataset[, vmr_madelantopesos := vm_madelantopesos / vm_mlimitecompra]

  if( atributos_presentes( c("vm_madelantodolares", "vm_mlimitecompra") ))
    dataset[, vmr_madelantodolares := vm_madelantodolares / vm_mlimitecompra]

  if( atributos_presentes( c("vm_mpagado", "vm_mlimitecompra") ))
    dataset[, vmr_mpagado := vm_mpagado / vm_mlimitecompra]

  if( atributos_presentes( c("vm_mpagospesos", "vm_mlimitecompra") ))
    dataset[, vmr_mpagospesos := vm_mpagospesos / vm_mlimitecompra]

  if( atributos_presentes( c("vm_mpagosdolares", "vm_mlimitecompra") ))
    dataset[, vmr_mpagosdolares := vm_mpagosdolares / vm_mlimitecompra]

  if( atributos_presentes( c("vm_mconsumototal", "vm_mlimitecompra") ))
    dataset[, vmr_mconsumototal := vm_mconsumototal / vm_mlimitecompra]

  if( atributos_presentes( c("vm_mpagominimo", "vm_mlimitecompra") ))
    dataset[, vmr_mpagominimo := vm_mpagominimo / vm_mlimitecompra]

  # Aqui debe usted agregar sus propias nuevas variables

  # valvula de seguridad para evitar valores infinitos
  # paso los infinitos a NULOS
  infinitos <- lapply(
    names(dataset),
    function(.name) dataset[, sum(is.infinite(get(.name)))]
  )

  infinitos_qty <- sum(unlist(infinitos))
  if (infinitos_qty > 0) {
    cat(
      "ATENCION, hay", infinitos_qty,
      "valores infinitos en tu dataset. Seran pasados a NA\n"
    )
    dataset[mapply(is.infinite, dataset)] <<- NA
  }


  # valvula de seguridad para evitar valores NaN  que es 0/0
  # paso los NaN a 0 , decision polemica si las hay
  # se invita a asignar un valor razonable segun la semantica del campo creado
  nans <- lapply(
    names(dataset),
    function(.name) dataset[, sum(is.nan(get(.name)))]
  )

  nans_qty <- sum(unlist(nans))
  if (nans_qty > 0) {
    cat(
      "ATENCION, hay", nans_qty,
      "valores NaN 0/0 en tu dataset. Seran pasados arbitrariamente a NA\n"
    )

    #cat("Si no te gusta la decision, modifica a gusto el programa!\n\n")
    dataset[mapply(is.nan, dataset)] <<- NA
  }

  cat( "fin AgregarVariables_IntraMes()\n")
}

# %%
# agrego las variables intra mes

AgregarVariables_IntraMes(dataset)
# Out:
# inicio AgregarVariables_IntraMes()
# fin AgregarVariables_IntraMes()

# %%
# visualizo las columas del dataset a esta etapa
ncol(dataset)
colnames(dataset)
# Out:
# [1] 69
#  [1] "numero_de_cliente"
#  [2] "foto_mes"
#  [3] "internet"
#  [4] "cliente_edad"
#  [5] "cliente_antiguedad"
#  [6] "cproductos"
#  [7] "cdescubierto_preacordado"
#  [8] "ctarjeta_visa"
#  [9] "ctarjeta_visa_transacciones"
# [10] "ctarjeta_master"
# [11] "ctarjeta_master_transacciones"
# [12] "cprestamos_personales"
# [13] "cpayroll_trx"
# [14] "ccomisiones_mantenimiento"
# [15] "ccomisiones_otras"
# [16] "ccallcenter_transacciones"
# [17] "thomebanking"
# [18] "chomebanking_transacciones"
# [19] "ctrx_quarter"
# [20] "Master_status"
# [21] "Master_Fvencimiento"
# [22] "Master_fultimo_cierre"
# [23] "Master_fechaalta"
# [24] "Master_cconsumos"
# [25] "Visa_status"
# [26] "Visa_Fvencimiento"
# [27] "Visa_fultimo_cierre"
# [28] "Visa_fechaalta"
# [29] "Visa_cconsumos"
# [30] "clase_ternaria"
# [31] "mrentabilidad_rank"
# [32] "mrentabilidad_annual_rank"
# [33] "mcomisiones_rank"
# [34] "mactivos_margen_rank"
# [35] "mpasivos_margen_rank"
# [36] "mcuenta_corriente_rank"
# [37] "mcaja_ahorro_rank"
# [38] "mcuentas_saldo_rank"
# [39] "mtarjeta_visa_consumo_rank"
# [40] "mtarjeta_master_consumo_rank"
# [41] "mprestamos_personales_rank"
# [42] "mpayroll_rank"
# [43] "mttarjeta_visa_debitos_automaticos_rank"
# [44] "mcomisiones_mantenimiento_rank"
# [45] "mtransferencias_recibidas_rank"
# [46] "Master_mfinanciacion_limite_rank"
# [47] "Master_msaldototal_rank"
# [48] "Master_mlimitecompra_rank"
# [49] "Master_mconsumototal_rank"
# [50] "Master_mpagominimo_rank"
# [51] "Visa_mfinanciacion_limite_rank"
# [52] "Visa_msaldototal_rank"
# [53] "Visa_mlimitecompra_rank"
# [54] "Visa_mconsumototal_rank"
# [55] "Visa_mpagominimo_rank"
# [56] "kmes"
# [57] "ctrx_quarter_normalizado"
# [58] "foto_mes_formato_fecha"
# [59] "vm_status01"
# [60] "vm_status02"
# [61] "vm_status03"
# [62] "vm_status04"
# [63] "vm_status05"
# [64] "vm_status06"
# [65] "mv_status07"
# [66] "vm_Fvencimiento"
# [67] "vm_fultimo_cierre"
# [68] "vm_fechaalta"
# [69] "vm_cconsumos"

# %% [markdown]
# #### 9.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 3
dataset[,
    paste0(cols_lagueables, "_lag3") := shift(.SD, 3, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
    dataset[, paste0(vcol, "_delta3") := get(vcol) - get(paste0(vcol, "_lag3"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 465
#   [1] "numero_de_cliente"
#   [2] "foto_mes"
#   [3] "internet"
#   [4] "cliente_edad"
#   [5] "cliente_antiguedad"
#   [6] "cproductos"
#   [7] "cdescubierto_preacordado"
#   [8] "ctarjeta_visa"
#   [9] "ctarjeta_visa_transacciones"
#  [10] "ctarjeta_master"
#  [11] "ctarjeta_master_transacciones"
#  [12] "cprestamos_personales"
#  [13] "cpayroll_trx"
#  [14] "ccomisiones_mantenimiento"
#  [15] "ccomisiones_otras"
#  [16] "ccallcenter_transacciones"
#  [17] "thomebanking"
#  [18] "chomebanking_transacciones"
#  [19] "ctrx_quarter"
#  [20] "Master_status"
#  [21] "Master_Fvencimiento"
#  [22] "Master_fultimo_cierre"
#  [23] "Master_fechaalta"
#  [24] "Master_cconsumos"
#  [25] "Visa_status"
#  [26] "Visa_Fvencimiento"
#  [27] "Visa_fultimo_cierre"
#  [28] "Visa_fechaalta"
#  [29] "Visa_cconsumos"
#  [30] "clase_ternaria"
#  [31] "mrentabilidad_rank"
#  [32] "mrentabilidad_annual_rank"
#  [33] "mcomisiones_rank"
#  [34] "mactivos_margen_rank"
#  [35] "mpasivos_margen_rank"
#  [36] "mcuenta_corriente_rank"
#  [37] "mcaja_ahorro_rank"
#  [38] "mcuentas_saldo_rank"
#  [39] "mtarjeta_visa_consumo_rank"
#  [40] "mtarjeta_master_consumo_rank"
#  [41] "mprestamos_personales_rank"
#  [42] "mpayroll_rank"
#  [43] "mttarjeta_visa_debitos_automaticos_rank"
#  [44] "mcomisiones_mantenimiento_rank"
#  [45] "mtransferencias_recibidas_rank"
#  [46] "Master_mfinanciacion_limite_rank"
#  [47] "Master_msaldototal_rank"
#  [48] "Master_mlimitecompra_rank"
#  [49] "Master_mconsumototal_rank"
#  [50] "Master_mpagominimo_rank"
#  [51] "Visa_mfinanciacion_limite_rank"
#  [52] "Visa_msaldototal_rank"
#  [53] "Visa_mlimitecompra_rank"
#  [54] "Visa_mconsumototal_rank"
#  [55] "Visa_mpagominimo_rank"
#  [56] "kmes"
#  [57] "ctrx_quarter_normalizado"
#  [58] "foto_mes_formato_fecha"
#  [59] "vm_status01"
#  [60] "vm_status02"
#  [61] "vm_status03"
#  [62] "vm_status04"
#  [63] "vm_status05"
#  [64] "vm_status06"
#  [65] "mv_status07"
#  [66] "vm_Fvencimiento"
#  [67] "vm_fultimo_cierre"
#  [68] "vm_fechaalta"
#  [69] "vm_cconsumos"
#  [70] "internet_lag1"
#  [71] "cliente_edad_lag1"
#  [72] "cliente_antiguedad_lag1"
#  [73] "cproductos_lag1"
#  [74] "cdescubierto_preacordado_lag1"
#  [75] "ctarjeta_visa_lag1"
#  [76] "ctarjeta_visa_transacciones_lag1"
#  [77] "ctarjeta_master_lag1"
#  [78] "ctarjeta_master_transacciones_lag1"
#  [79] "cprestamos_personales_lag1"
#  [80] "cpayroll_trx_lag1"
#  [81] "ccomisiones_mantenimiento_lag1"
#  [82] "ccomisiones_otras_lag1"
#  [83] "ccallcenter_transacciones_lag1"
#  [84] "thomebanking_lag1"
#  [85] "chomebanking_transacciones_lag1"
#  [86] "ctrx_quarter_lag1"
#  [87] "Master_status_lag1"
#  [88] "Master_Fvencimiento_lag1"
#  [89] "Master_fultimo_cierre_lag1"
#  [90] "Master_fechaalta_lag1"
#  [91] "Master_cconsumos_lag1"
#  [92] "Visa_status_lag1"
#  [93] "Visa_Fvencimiento_lag1"
#  [94] "Visa_fultimo_cierre_lag1"
#  [95] "Visa_fechaalta_lag1"
#  [96] "Visa_cconsumos_lag1"
#  [97] "mrentabilidad_rank_lag1"
#  [98] "mrentabilidad_annual_rank_lag1"
#  [99] "mcomisiones_rank_lag1"
# [100] "mactivos_margen_rank_lag1"
# [101] "mpasivos_margen_rank_lag1"
# [102] "mcuenta_corriente_rank_lag1"
# [103] "mcaja_ahorro_rank_lag1"
# [104] "mcuentas_saldo_rank_lag1"
# [105] "mtarjeta_visa_consumo_rank_lag1"
# [106] "mtarjeta_master_consumo_rank_lag1"
# [107] "mprestamos_personales_rank_lag1"
# [108] "mpayroll_rank_lag1"
# [109] "mttarjeta_visa_debitos_automaticos_rank_lag1"
# [110] "mcomisiones_mantenimiento_rank_lag1"
# [111] "mtransferencias_recibidas_rank_lag1"
# [112] "Master_mfinanciacion_limite_rank_lag1"
# [113] "Master_msaldototal_rank_lag1"
# [114] "Master_mlimitecompra_rank_lag1"
# [115] "Master_mconsumototal_rank_lag1"
# [116] "Master_mpagominimo_rank_lag1"
# [117] "Visa_mfinanciacion_limite_rank_lag1"
# [118] "Visa_msaldototal_rank_lag1"
# [119] "Visa_mlimitecompra_rank_lag1"
# [120] "Visa_mconsumototal_rank_lag1"
# [121] "Visa_mpagominimo_rank_lag1"
# [122] "kmes_lag1"
# [123] "ctrx_quarter_normalizado_lag1"
# [124] "foto_mes_formato_fecha_lag1"
# [125] "vm_status01_lag1"
# [126] "vm_status02_lag1"
# [127] "vm_status03_lag1"
# [128] "vm_status04_lag1"
# [129] "vm_status05_lag1"
# [130] "vm_status06_lag1"
# [131] "mv_status07_lag1"
# [132] "vm_Fvencimiento_lag1"
# [133] "vm_fultimo_cierre_lag1"
# [134] "vm_fechaalta_lag1"
# [135] "vm_cconsumos_lag1"
# [136] "internet_lag2"
# [137] "cliente_edad_lag2"
# [138] "cliente_antiguedad_lag2"
# [139] "cproductos_lag2"
# [140] "cdescubierto_preacordado_lag2"
# [141] "ctarjeta_visa_lag2"
# [142] "ctarjeta_visa_transacciones_lag2"
# [143] "ctarjeta_master_lag2"
# [144] "ctarjeta_master_transacciones_lag2"
# [145] "cprestamos_personales_lag2"
# [146] "cpayroll_trx_lag2"
# [147] "ccomisiones_mantenimiento_lag2"
# [148] "ccomisiones_otras_lag2"
# [149] "ccallcenter_transacciones_lag2"
# [150] "thomebanking_lag2"
# [151] "chomebanking_transacciones_lag2"
# [152] "ctrx_quarter_lag2"
# [153] "Master_status_lag2"
# [154] "Master_Fvencimiento_lag2"
# [155] "Master_fultimo_cierre_lag2"
# [156] "Master_fechaalta_lag2"
# [157] "Master_cconsumos_lag2"
# [158] "Visa_status_lag2"
# [159] "Visa_Fvencimiento_lag2"
# [160] "Visa_fultimo_cierre_lag2"
# [161] "Visa_fechaalta_lag2"
# [162] "Visa_cconsumos_lag2"
# [163] "mrentabilidad_rank_lag2"
# [164] "mrentabilidad_annual_rank_lag2"
# [165] "mcomisiones_rank_lag2"
# [166] "mactivos_margen_rank_lag2"
# [167] "mpasivos_margen_rank_lag2"
# [168] "mcuenta_corriente_rank_lag2"
# [169] "mcaja_ahorro_rank_lag2"
# [170] "mcuentas_saldo_rank_lag2"
# [171] "mtarjeta_visa_consumo_rank_lag2"
# [172] "mtarjeta_master_consumo_rank_lag2"
# [173] "mprestamos_personales_rank_lag2"
# [174] "mpayroll_rank_lag2"
# [175] "mttarjeta_visa_debitos_automaticos_rank_lag2"
# [176] "mcomisiones_mantenimiento_rank_lag2"
# [177] "mtransferencias_recibidas_rank_lag2"
# [178] "Master_mfinanciacion_limite_rank_lag2"
# [179] "Master_msaldototal_rank_lag2"
# [180] "Master_mlimitecompra_rank_lag2"
# [181] "Master_mconsumototal_rank_lag2"
# [182] "Master_mpagominimo_rank_lag2"
# [183] "Visa_mfinanciacion_limite_rank_lag2"
# [184] "Visa_msaldototal_rank_lag2"
# [185] "Visa_mlimitecompra_rank_lag2"
# [186] "Visa_mconsumototal_rank_lag2"
# [187] "Visa_mpagominimo_rank_lag2"
# [188] "kmes_lag2"
# [189] "ctrx_quarter_normalizado_lag2"
# [190] "foto_mes_formato_fecha_lag2"
# [191] "vm_status01_lag2"
# [192] "vm_status02_lag2"
# [193] "vm_status03_lag2"
# [194] "vm_status04_lag2"
# [195] "vm_status05_lag2"
# [196] "vm_status06_lag2"
# [197] "mv_status07_lag2"
# [198] "vm_Fvencimiento_lag2"
# [199] "vm_fultimo_cierre_lag2"
# [200] "vm_fechaalta_lag2"
# [201] "vm_cconsumos_lag2"
# [202] "internet_lag3"
# [203] "cliente_edad_lag3"
# [204] "cliente_antiguedad_lag3"
# [205] "cproductos_lag3"
# [206] "cdescubierto_preacordado_lag3"
# [207] "ctarjeta_visa_lag3"
# [208] "ctarjeta_visa_transacciones_lag3"
# [209] "ctarjeta_master_lag3"
# [210] "ctarjeta_master_transacciones_lag3"
# [211] "cprestamos_personales_lag3"
# [212] "cpayroll_trx_lag3"
# [213] "ccomisiones_mantenimiento_lag3"
# [214] "ccomisiones_otras_lag3"
# [215] "ccallcenter_transacciones_lag3"
# [216] "thomebanking_lag3"
# [217] "chomebanking_transacciones_lag3"
# [218] "ctrx_quarter_lag3"
# [219] "Master_status_lag3"
# [220] "Master_Fvencimiento_lag3"
# [221] "Master_fultimo_cierre_lag3"
# [222] "Master_fechaalta_lag3"
# [223] "Master_cconsumos_lag3"
# [224] "Visa_status_lag3"
# [225] "Visa_Fvencimiento_lag3"
# [226] "Visa_fultimo_cierre_lag3"
# [227] "Visa_fechaalta_lag3"
# [228] "Visa_cconsumos_lag3"
# [229] "mrentabilidad_rank_lag3"
# [230] "mrentabilidad_annual_rank_lag3"
# [231] "mcomisiones_rank_lag3"
# [232] "mactivos_margen_rank_lag3"
# [233] "mpasivos_margen_rank_lag3"
# [234] "mcuenta_corriente_rank_lag3"
# [235] "mcaja_ahorro_rank_lag3"
# [236] "mcuentas_saldo_rank_lag3"
# [237] "mtarjeta_visa_consumo_rank_lag3"
# [238] "mtarjeta_master_consumo_rank_lag3"
# [239] "mprestamos_personales_rank_lag3"
# [240] "mpayroll_rank_lag3"
# [241] "mttarjeta_visa_debitos_automaticos_rank_lag3"
# [242] "mcomisiones_mantenimiento_rank_lag3"
# [243] "mtransferencias_recibidas_rank_lag3"
# [244] "Master_mfinanciacion_limite_rank_lag3"
# [245] "Master_msaldototal_rank_lag3"
# [246] "Master_mlimitecompra_rank_lag3"
# [247] "Master_mconsumototal_rank_lag3"
# [248] "Master_mpagominimo_rank_lag3"
# [249] "Visa_mfinanciacion_limite_rank_lag3"
# [250] "Visa_msaldototal_rank_lag3"
# [251] "Visa_mlimitecompra_rank_lag3"
# [252] "Visa_mconsumototal_rank_lag3"
# [253] "Visa_mpagominimo_rank_lag3"
# [254] "kmes_lag3"
# [255] "ctrx_quarter_normalizado_lag3"
# [256] "foto_mes_formato_fecha_lag3"
# [257] "vm_status01_lag3"
# [258] "vm_status02_lag3"
# [259] "vm_status03_lag3"
# [260] "vm_status04_lag3"
# [261] "vm_status05_lag3"
# [262] "vm_status06_lag3"
# [263] "mv_status07_lag3"
# [264] "vm_Fvencimiento_lag3"
# [265] "vm_fultimo_cierre_lag3"
# [266] "vm_fechaalta_lag3"
# [267] "vm_cconsumos_lag3"
# [268] "internet_delta1"
# [269] "internet_delta2"
# [270] "internet_delta3"
# [271] "cliente_edad_delta1"
# [272] "cliente_edad_delta2"
# [273] "cliente_edad_delta3"
# [274] "cliente_antiguedad_delta1"
# [275] "cliente_antiguedad_delta2"
# [276] "cliente_antiguedad_delta3"
# [277] "cproductos_delta1"
# [278] "cproductos_delta2"
# [279] "cproductos_delta3"
# [280] "cdescubierto_preacordado_delta1"
# [281] "cdescubierto_preacordado_delta2"
# [282] "cdescubierto_preacordado_delta3"
# [283] "ctarjeta_visa_delta1"
# [284] "ctarjeta_visa_delta2"
# [285] "ctarjeta_visa_delta3"
# [286] "ctarjeta_visa_transacciones_delta1"
# [287] "ctarjeta_visa_transacciones_delta2"
# [288] "ctarjeta_visa_transacciones_delta3"
# [289] "ctarjeta_master_delta1"
# [290] "ctarjeta_master_delta2"
# [291] "ctarjeta_master_delta3"
# [292] "ctarjeta_master_transacciones_delta1"
# [293] "ctarjeta_master_transacciones_delta2"
# [294] "ctarjeta_master_transacciones_delta3"
# [295] "cprestamos_personales_delta1"
# [296] "cprestamos_personales_delta2"
# [297] "cprestamos_personales_delta3"
# [298] "cpayroll_trx_delta1"
# [299] "cpayroll_trx_delta2"
# [300] "cpayroll_trx_delta3"
# [301] "ccomisiones_mantenimiento_delta1"
# [302] "ccomisiones_mantenimiento_delta2"
# [303] "ccomisiones_mantenimiento_delta3"
# [304] "ccomisiones_otras_delta1"
# [305] "ccomisiones_otras_delta2"
# [306] "ccomisiones_otras_delta3"
# [307] "ccallcenter_transacciones_delta1"
# [308] "ccallcenter_transacciones_delta2"
# [309] "ccallcenter_transacciones_delta3"
# [310] "thomebanking_delta1"
# [311] "thomebanking_delta2"
# [312] "thomebanking_delta3"
# [313] "chomebanking_transacciones_delta1"
# [314] "chomebanking_transacciones_delta2"
# [315] "chomebanking_transacciones_delta3"
# [316] "ctrx_quarter_delta1"
# [317] "ctrx_quarter_delta2"
# [318] "ctrx_quarter_delta3"
# [319] "Master_status_delta1"
# [320] "Master_status_delta2"
# [321] "Master_status_delta3"
# [322] "Master_Fvencimiento_delta1"
# [323] "Master_Fvencimiento_delta2"
# [324] "Master_Fvencimiento_delta3"
# [325] "Master_fultimo_cierre_delta1"
# [326] "Master_fultimo_cierre_delta2"
# [327] "Master_fultimo_cierre_delta3"
# [328] "Master_fechaalta_delta1"
# [329] "Master_fechaalta_delta2"
# [330] "Master_fechaalta_delta3"
# [331] "Master_cconsumos_delta1"
# [332] "Master_cconsumos_delta2"
# [333] "Master_cconsumos_delta3"
# [334] "Visa_status_delta1"
# [335] "Visa_status_delta2"
# [336] "Visa_status_delta3"
# [337] "Visa_Fvencimiento_delta1"
# [338] "Visa_Fvencimiento_delta2"
# [339] "Visa_Fvencimiento_delta3"
# [340] "Visa_fultimo_cierre_delta1"
# [341] "Visa_fultimo_cierre_delta2"
# [342] "Visa_fultimo_cierre_delta3"
# [343] "Visa_fechaalta_delta1"
# [344] "Visa_fechaalta_delta2"
# [345] "Visa_fechaalta_delta3"
# [346] "Visa_cconsumos_delta1"
# [347] "Visa_cconsumos_delta2"
# [348] "Visa_cconsumos_delta3"
# [349] "mrentabilidad_rank_delta1"
# [350] "mrentabilidad_rank_delta2"
# [351] "mrentabilidad_rank_delta3"
# [352] "mrentabilidad_annual_rank_delta1"
# [353] "mrentabilidad_annual_rank_delta2"
# [354] "mrentabilidad_annual_rank_delta3"
# [355] "mcomisiones_rank_delta1"
# [356] "mcomisiones_rank_delta2"
# [357] "mcomisiones_rank_delta3"
# [358] "mactivos_margen_rank_delta1"
# [359] "mactivos_margen_rank_delta2"
# [360] "mactivos_margen_rank_delta3"
# [361] "mpasivos_margen_rank_delta1"
# [362] "mpasivos_margen_rank_delta2"
# [363] "mpasivos_margen_rank_delta3"
# [364] "mcuenta_corriente_rank_delta1"
# [365] "mcuenta_corriente_rank_delta2"
# [366] "mcuenta_corriente_rank_delta3"
# [367] "mcaja_ahorro_rank_delta1"
# [368] "mcaja_ahorro_rank_delta2"
# [369] "mcaja_ahorro_rank_delta3"
# [370] "mcuentas_saldo_rank_delta1"
# [371] "mcuentas_saldo_rank_delta2"
# [372] "mcuentas_saldo_rank_delta3"
# [373] "mtarjeta_visa_consumo_rank_delta1"
# [374] "mtarjeta_visa_consumo_rank_delta2"
# [375] "mtarjeta_visa_consumo_rank_delta3"
# [376] "mtarjeta_master_consumo_rank_delta1"
# [377] "mtarjeta_master_consumo_rank_delta2"
# [378] "mtarjeta_master_consumo_rank_delta3"
# [379] "mprestamos_personales_rank_delta1"
# [380] "mprestamos_personales_rank_delta2"
# [381] "mprestamos_personales_rank_delta3"
# [382] "mpayroll_rank_delta1"
# [383] "mpayroll_rank_delta2"
# [384] "mpayroll_rank_delta3"
# [385] "mttarjeta_visa_debitos_automaticos_rank_delta1"
# [386] "mttarjeta_visa_debitos_automaticos_rank_delta2"
# [387] "mttarjeta_visa_debitos_automaticos_rank_delta3"
# [388] "mcomisiones_mantenimiento_rank_delta1"
# [389] "mcomisiones_mantenimiento_rank_delta2"
# [390] "mcomisiones_mantenimiento_rank_delta3"
# [391] "mtransferencias_recibidas_rank_delta1"
# [392] "mtransferencias_recibidas_rank_delta2"
# [393] "mtransferencias_recibidas_rank_delta3"
# [394] "Master_mfinanciacion_limite_rank_delta1"
# [395] "Master_mfinanciacion_limite_rank_delta2"
# [396] "Master_mfinanciacion_limite_rank_delta3"
# [397] "Master_msaldototal_rank_delta1"
# [398] "Master_msaldototal_rank_delta2"
# [399] "Master_msaldototal_rank_delta3"
# [400] "Master_mlimitecompra_rank_delta1"
# [401] "Master_mlimitecompra_rank_delta2"
# [402] "Master_mlimitecompra_rank_delta3"
# [403] "Master_mconsumototal_rank_delta1"
# [404] "Master_mconsumototal_rank_delta2"
# [405] "Master_mconsumototal_rank_delta3"
# [406] "Master_mpagominimo_rank_delta1"
# [407] "Master_mpagominimo_rank_delta2"
# [408] "Master_mpagominimo_rank_delta3"
# [409] "Visa_mfinanciacion_limite_rank_delta1"
# [410] "Visa_mfinanciacion_limite_rank_delta2"
# [411] "Visa_mfinanciacion_limite_rank_delta3"
# [412] "Visa_msaldototal_rank_delta1"
# [413] "Visa_msaldototal_rank_delta2"
# [414] "Visa_msaldototal_rank_delta3"
# [415] "Visa_mlimitecompra_rank_delta1"
# [416] "Visa_mlimitecompra_rank_delta2"
# [417] "Visa_mlimitecompra_rank_delta3"
# [418] "Visa_mconsumototal_rank_delta1"
# [419] "Visa_mconsumototal_rank_delta2"
# [420] "Visa_mconsumototal_rank_delta3"
# [421] "Visa_mpagominimo_rank_delta1"
# [422] "Visa_mpagominimo_rank_delta2"
# [423] "Visa_mpagominimo_rank_delta3"
# [424] "kmes_delta1"
# [425] "kmes_delta2"
# [426] "kmes_delta3"
# [427] "ctrx_quarter_normalizado_delta1"
# [428] "ctrx_quarter_normalizado_delta2"
# [429] "ctrx_quarter_normalizado_delta3"
# [430] "foto_mes_formato_fecha_delta1"
# [431] "foto_mes_formato_fecha_delta2"
# [432] "foto_mes_formato_fecha_delta3"
# [433] "vm_status01_delta1"
# [434] "vm_status01_delta2"
# [435] "vm_status01_delta3"
# [436] "vm_status02_delta1"
# [437] "vm_status02_delta2"
# [438] "vm_status02_delta3"
# [439] "vm_status03_delta1"
# [440] "vm_status03_delta2"
# [441] "vm_status03_delta3"
# [442] "vm_status04_delta1"
# [443] "vm_status04_delta2"
# [444] "vm_status04_delta3"
# [445] "vm_status05_delta1"
# [446] "vm_status05_delta2"
# [447] "vm_status05_delta3"
# [448] "vm_status06_delta1"
# [449] "vm_status06_delta2"
# [450] "vm_status06_delta3"
# [451] "mv_status07_delta1"
# [452] "mv_status07_delta2"
# [453] "mv_status07_delta3"
# [454] "vm_Fvencimiento_delta1"
# [455] "vm_Fvencimiento_delta2"
# [456] "vm_Fvencimiento_delta3"
# [457] "vm_fultimo_cierre_delta1"
# [458] "vm_fultimo_cierre_delta2"
# [459] "vm_fultimo_cierre_delta3"
# [460] "vm_fechaalta_delta1"
# [461] "vm_fechaalta_delta2"
# [462] "vm_fechaalta_delta3"
# [463] "vm_cconsumos_delta1"
# [464] "vm_cconsumos_delta2"
# [465] "vm_cconsumos_delta3"

# %%
#### 9.3.1.5 FE Feature Engineering financiero

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 465
#   [1] "numero_de_cliente"
#   [2] "foto_mes"
#   [3] "internet"
#   [4] "cliente_edad"
#   [5] "cliente_antiguedad"
#   [6] "cproductos"
#   [7] "cdescubierto_preacordado"
#   [8] "ctarjeta_visa"
#   [9] "ctarjeta_visa_transacciones"
#  [10] "ctarjeta_master"
#  [11] "ctarjeta_master_transacciones"
#  [12] "cprestamos_personales"
#  [13] "cpayroll_trx"
#  [14] "ccomisiones_mantenimiento"
#  [15] "ccomisiones_otras"
#  [16] "ccallcenter_transacciones"
#  [17] "thomebanking"
#  [18] "chomebanking_transacciones"
#  [19] "ctrx_quarter"
#  [20] "Master_status"
#  [21] "Master_Fvencimiento"
#  [22] "Master_fultimo_cierre"
#  [23] "Master_fechaalta"
#  [24] "Master_cconsumos"
#  [25] "Visa_status"
#  [26] "Visa_Fvencimiento"
#  [27] "Visa_fultimo_cierre"
#  [28] "Visa_fechaalta"
#  [29] "Visa_cconsumos"
#  [30] "clase_ternaria"
#  [31] "mrentabilidad_rank"
#  [32] "mrentabilidad_annual_rank"
#  [33] "mcomisiones_rank"
#  [34] "mactivos_margen_rank"
#  [35] "mpasivos_margen_rank"
#  [36] "mcuenta_corriente_rank"
#  [37] "mcaja_ahorro_rank"
#  [38] "mcuentas_saldo_rank"
#  [39] "mtarjeta_visa_consumo_rank"
#  [40] "mtarjeta_master_consumo_rank"
#  [41] "mprestamos_personales_rank"
#  [42] "mpayroll_rank"
#  [43] "mttarjeta_visa_debitos_automaticos_rank"
#  [44] "mcomisiones_mantenimiento_rank"
#  [45] "mtransferencias_recibidas_rank"
#  [46] "Master_mfinanciacion_limite_rank"
#  [47] "Master_msaldototal_rank"
#  [48] "Master_mlimitecompra_rank"
#  [49] "Master_mconsumototal_rank"
#  [50] "Master_mpagominimo_rank"
#  [51] "Visa_mfinanciacion_limite_rank"
#  [52] "Visa_msaldototal_rank"
#  [53] "Visa_mlimitecompra_rank"
#  [54] "Visa_mconsumototal_rank"
#  [55] "Visa_mpagominimo_rank"
#  [56] "kmes"
#  [57] "ctrx_quarter_normalizado"
#  [58] "foto_mes_formato_fecha"
#  [59] "vm_status01"
#  [60] "vm_status02"
#  [61] "vm_status03"
#  [62] "vm_status04"
#  [63] "vm_status05"
#  [64] "vm_status06"
#  [65] "mv_status07"
#  [66] "vm_Fvencimiento"
#  [67] "vm_fultimo_cierre"
#  [68] "vm_fechaalta"
#  [69] "vm_cconsumos"
#  [70] "internet_lag1"
#  [71] "cliente_edad_lag1"
#  [72] "cliente_antiguedad_lag1"
#  [73] "cproductos_lag1"
#  [74] "cdescubierto_preacordado_lag1"
#  [75] "ctarjeta_visa_lag1"
#  [76] "ctarjeta_visa_transacciones_lag1"
#  [77] "ctarjeta_master_lag1"
#  [78] "ctarjeta_master_transacciones_lag1"
#  [79] "cprestamos_personales_lag1"
#  [80] "cpayroll_trx_lag1"
#  [81] "ccomisiones_mantenimiento_lag1"
#  [82] "ccomisiones_otras_lag1"
#  [83] "ccallcenter_transacciones_lag1"
#  [84] "thomebanking_lag1"
#  [85] "chomebanking_transacciones_lag1"
#  [86] "ctrx_quarter_lag1"
#  [87] "Master_status_lag1"
#  [88] "Master_Fvencimiento_lag1"
#  [89] "Master_fultimo_cierre_lag1"
#  [90] "Master_fechaalta_lag1"
#  [91] "Master_cconsumos_lag1"
#  [92] "Visa_status_lag1"
#  [93] "Visa_Fvencimiento_lag1"
#  [94] "Visa_fultimo_cierre_lag1"
#  [95] "Visa_fechaalta_lag1"
#  [96] "Visa_cconsumos_lag1"
#  [97] "mrentabilidad_rank_lag1"
#  [98] "mrentabilidad_annual_rank_lag1"
#  [99] "mcomisiones_rank_lag1"
# [100] "mactivos_margen_rank_lag1"
# [101] "mpasivos_margen_rank_lag1"
# [102] "mcuenta_corriente_rank_lag1"
# [103] "mcaja_ahorro_rank_lag1"
# [104] "mcuentas_saldo_rank_lag1"
# [105] "mtarjeta_visa_consumo_rank_lag1"
# [106] "mtarjeta_master_consumo_rank_lag1"
# [107] "mprestamos_personales_rank_lag1"
# [108] "mpayroll_rank_lag1"
# [109] "mttarjeta_visa_debitos_automaticos_rank_lag1"
# [110] "mcomisiones_mantenimiento_rank_lag1"
# [111] "mtransferencias_recibidas_rank_lag1"
# [112] "Master_mfinanciacion_limite_rank_lag1"
# [113] "Master_msaldototal_rank_lag1"
# [114] "Master_mlimitecompra_rank_lag1"
# [115] "Master_mconsumototal_rank_lag1"
# [116] "Master_mpagominimo_rank_lag1"
# [117] "Visa_mfinanciacion_limite_rank_lag1"
# [118] "Visa_msaldototal_rank_lag1"
# [119] "Visa_mlimitecompra_rank_lag1"
# [120] "Visa_mconsumototal_rank_lag1"
# [121] "Visa_mpagominimo_rank_lag1"
# [122] "kmes_lag1"
# [123] "ctrx_quarter_normalizado_lag1"
# [124] "foto_mes_formato_fecha_lag1"
# [125] "vm_status01_lag1"
# [126] "vm_status02_lag1"
# [127] "vm_status03_lag1"
# [128] "vm_status04_lag1"
# [129] "vm_status05_lag1"
# [130] "vm_status06_lag1"
# [131] "mv_status07_lag1"
# [132] "vm_Fvencimiento_lag1"
# [133] "vm_fultimo_cierre_lag1"
# [134] "vm_fechaalta_lag1"
# [135] "vm_cconsumos_lag1"
# [136] "internet_lag2"
# [137] "cliente_edad_lag2"
# [138] "cliente_antiguedad_lag2"
# [139] "cproductos_lag2"
# [140] "cdescubierto_preacordado_lag2"
# [141] "ctarjeta_visa_lag2"
# [142] "ctarjeta_visa_transacciones_lag2"
# [143] "ctarjeta_master_lag2"
# [144] "ctarjeta_master_transacciones_lag2"
# [145] "cprestamos_personales_lag2"
# [146] "cpayroll_trx_lag2"
# [147] "ccomisiones_mantenimiento_lag2"
# [148] "ccomisiones_otras_lag2"
# [149] "ccallcenter_transacciones_lag2"
# [150] "thomebanking_lag2"
# [151] "chomebanking_transacciones_lag2"
# [152] "ctrx_quarter_lag2"
# [153] "Master_status_lag2"
# [154] "Master_Fvencimiento_lag2"
# [155] "Master_fultimo_cierre_lag2"
# [156] "Master_fechaalta_lag2"
# [157] "Master_cconsumos_lag2"
# [158] "Visa_status_lag2"
# [159] "Visa_Fvencimiento_lag2"
# [160] "Visa_fultimo_cierre_lag2"
# [161] "Visa_fechaalta_lag2"
# [162] "Visa_cconsumos_lag2"
# [163] "mrentabilidad_rank_lag2"
# [164] "mrentabilidad_annual_rank_lag2"
# [165] "mcomisiones_rank_lag2"
# [166] "mactivos_margen_rank_lag2"
# [167] "mpasivos_margen_rank_lag2"
# [168] "mcuenta_corriente_rank_lag2"
# [169] "mcaja_ahorro_rank_lag2"
# [170] "mcuentas_saldo_rank_lag2"
# [171] "mtarjeta_visa_consumo_rank_lag2"
# [172] "mtarjeta_master_consumo_rank_lag2"
# [173] "mprestamos_personales_rank_lag2"
# [174] "mpayroll_rank_lag2"
# [175] "mttarjeta_visa_debitos_automaticos_rank_lag2"
# [176] "mcomisiones_mantenimiento_rank_lag2"
# [177] "mtransferencias_recibidas_rank_lag2"
# [178] "Master_mfinanciacion_limite_rank_lag2"
# [179] "Master_msaldototal_rank_lag2"
# [180] "Master_mlimitecompra_rank_lag2"
# [181] "Master_mconsumototal_rank_lag2"
# [182] "Master_mpagominimo_rank_lag2"
# [183] "Visa_mfinanciacion_limite_rank_lag2"
# [184] "Visa_msaldototal_rank_lag2"
# [185] "Visa_mlimitecompra_rank_lag2"
# [186] "Visa_mconsumototal_rank_lag2"
# [187] "Visa_mpagominimo_rank_lag2"
# [188] "kmes_lag2"
# [189] "ctrx_quarter_normalizado_lag2"
# [190] "foto_mes_formato_fecha_lag2"
# [191] "vm_status01_lag2"
# [192] "vm_status02_lag2"
# [193] "vm_status03_lag2"
# [194] "vm_status04_lag2"
# [195] "vm_status05_lag2"
# [196] "vm_status06_lag2"
# [197] "mv_status07_lag2"
# [198] "vm_Fvencimiento_lag2"
# [199] "vm_fultimo_cierre_lag2"
# [200] "vm_fechaalta_lag2"
# [201] "vm_cconsumos_lag2"
# [202] "internet_lag3"
# [203] "cliente_edad_lag3"
# [204] "cliente_antiguedad_lag3"
# [205] "cproductos_lag3"
# [206] "cdescubierto_preacordado_lag3"
# [207] "ctarjeta_visa_lag3"
# [208] "ctarjeta_visa_transacciones_lag3"
# [209] "ctarjeta_master_lag3"
# [210] "ctarjeta_master_transacciones_lag3"
# [211] "cprestamos_personales_lag3"
# [212] "cpayroll_trx_lag3"
# [213] "ccomisiones_mantenimiento_lag3"
# [214] "ccomisiones_otras_lag3"
# [215] "ccallcenter_transacciones_lag3"
# [216] "thomebanking_lag3"
# [217] "chomebanking_transacciones_lag3"
# [218] "ctrx_quarter_lag3"
# [219] "Master_status_lag3"
# [220] "Master_Fvencimiento_lag3"
# [221] "Master_fultimo_cierre_lag3"
# [222] "Master_fechaalta_lag3"
# [223] "Master_cconsumos_lag3"
# [224] "Visa_status_lag3"
# [225] "Visa_Fvencimiento_lag3"
# [226] "Visa_fultimo_cierre_lag3"
# [227] "Visa_fechaalta_lag3"
# [228] "Visa_cconsumos_lag3"
# [229] "mrentabilidad_rank_lag3"
# [230] "mrentabilidad_annual_rank_lag3"
# [231] "mcomisiones_rank_lag3"
# [232] "mactivos_margen_rank_lag3"
# [233] "mpasivos_margen_rank_lag3"
# [234] "mcuenta_corriente_rank_lag3"
# [235] "mcaja_ahorro_rank_lag3"
# [236] "mcuentas_saldo_rank_lag3"
# [237] "mtarjeta_visa_consumo_rank_lag3"
# [238] "mtarjeta_master_consumo_rank_lag3"
# [239] "mprestamos_personales_rank_lag3"
# [240] "mpayroll_rank_lag3"
# [241] "mttarjeta_visa_debitos_automaticos_rank_lag3"
# [242] "mcomisiones_mantenimiento_rank_lag3"
# [243] "mtransferencias_recibidas_rank_lag3"
# [244] "Master_mfinanciacion_limite_rank_lag3"
# [245] "Master_msaldototal_rank_lag3"
# [246] "Master_mlimitecompra_rank_lag3"
# [247] "Master_mconsumototal_rank_lag3"
# [248] "Master_mpagominimo_rank_lag3"
# [249] "Visa_mfinanciacion_limite_rank_lag3"
# [250] "Visa_msaldototal_rank_lag3"
# [251] "Visa_mlimitecompra_rank_lag3"
# [252] "Visa_mconsumototal_rank_lag3"
# [253] "Visa_mpagominimo_rank_lag3"
# [254] "kmes_lag3"
# [255] "ctrx_quarter_normalizado_lag3"
# [256] "foto_mes_formato_fecha_lag3"
# [257] "vm_status01_lag3"
# [258] "vm_status02_lag3"
# [259] "vm_status03_lag3"
# [260] "vm_status04_lag3"
# [261] "vm_status05_lag3"
# [262] "vm_status06_lag3"
# [263] "mv_status07_lag3"
# [264] "vm_Fvencimiento_lag3"
# [265] "vm_fultimo_cierre_lag3"
# [266] "vm_fechaalta_lag3"
# [267] "vm_cconsumos_lag3"
# [268] "internet_delta1"
# [269] "internet_delta2"
# [270] "internet_delta3"
# [271] "cliente_edad_delta1"
# [272] "cliente_edad_delta2"
# [273] "cliente_edad_delta3"
# [274] "cliente_antiguedad_delta1"
# [275] "cliente_antiguedad_delta2"
# [276] "cliente_antiguedad_delta3"
# [277] "cproductos_delta1"
# [278] "cproductos_delta2"
# [279] "cproductos_delta3"
# [280] "cdescubierto_preacordado_delta1"
# [281] "cdescubierto_preacordado_delta2"
# [282] "cdescubierto_preacordado_delta3"
# [283] "ctarjeta_visa_delta1"
# [284] "ctarjeta_visa_delta2"
# [285] "ctarjeta_visa_delta3"
# [286] "ctarjeta_visa_transacciones_delta1"
# [287] "ctarjeta_visa_transacciones_delta2"
# [288] "ctarjeta_visa_transacciones_delta3"
# [289] "ctarjeta_master_delta1"
# [290] "ctarjeta_master_delta2"
# [291] "ctarjeta_master_delta3"
# [292] "ctarjeta_master_transacciones_delta1"
# [293] "ctarjeta_master_transacciones_delta2"
# [294] "ctarjeta_master_transacciones_delta3"
# [295] "cprestamos_personales_delta1"
# [296] "cprestamos_personales_delta2"
# [297] "cprestamos_personales_delta3"
# [298] "cpayroll_trx_delta1"
# [299] "cpayroll_trx_delta2"
# [300] "cpayroll_trx_delta3"
# [301] "ccomisiones_mantenimiento_delta1"
# [302] "ccomisiones_mantenimiento_delta2"
# [303] "ccomisiones_mantenimiento_delta3"
# [304] "ccomisiones_otras_delta1"
# [305] "ccomisiones_otras_delta2"
# [306] "ccomisiones_otras_delta3"
# [307] "ccallcenter_transacciones_delta1"
# [308] "ccallcenter_transacciones_delta2"
# [309] "ccallcenter_transacciones_delta3"
# [310] "thomebanking_delta1"
# [311] "thomebanking_delta2"
# [312] "thomebanking_delta3"
# [313] "chomebanking_transacciones_delta1"
# [314] "chomebanking_transacciones_delta2"
# [315] "chomebanking_transacciones_delta3"
# [316] "ctrx_quarter_delta1"
# [317] "ctrx_quarter_delta2"
# [318] "ctrx_quarter_delta3"
# [319] "Master_status_delta1"
# [320] "Master_status_delta2"
# [321] "Master_status_delta3"
# [322] "Master_Fvencimiento_delta1"
# [323] "Master_Fvencimiento_delta2"
# [324] "Master_Fvencimiento_delta3"
# [325] "Master_fultimo_cierre_delta1"
# [326] "Master_fultimo_cierre_delta2"
# [327] "Master_fultimo_cierre_delta3"
# [328] "Master_fechaalta_delta1"
# [329] "Master_fechaalta_delta2"
# [330] "Master_fechaalta_delta3"
# [331] "Master_cconsumos_delta1"
# [332] "Master_cconsumos_delta2"
# [333] "Master_cconsumos_delta3"
# [334] "Visa_status_delta1"
# [335] "Visa_status_delta2"
# [336] "Visa_status_delta3"
# [337] "Visa_Fvencimiento_delta1"
# [338] "Visa_Fvencimiento_delta2"
# [339] "Visa_Fvencimiento_delta3"
# [340] "Visa_fultimo_cierre_delta1"
# [341] "Visa_fultimo_cierre_delta2"
# [342] "Visa_fultimo_cierre_delta3"
# [343] "Visa_fechaalta_delta1"
# [344] "Visa_fechaalta_delta2"
# [345] "Visa_fechaalta_delta3"
# [346] "Visa_cconsumos_delta1"
# [347] "Visa_cconsumos_delta2"
# [348] "Visa_cconsumos_delta3"
# [349] "mrentabilidad_rank_delta1"
# [350] "mrentabilidad_rank_delta2"
# [351] "mrentabilidad_rank_delta3"
# [352] "mrentabilidad_annual_rank_delta1"
# [353] "mrentabilidad_annual_rank_delta2"
# [354] "mrentabilidad_annual_rank_delta3"
# [355] "mcomisiones_rank_delta1"
# [356] "mcomisiones_rank_delta2"
# [357] "mcomisiones_rank_delta3"
# [358] "mactivos_margen_rank_delta1"
# [359] "mactivos_margen_rank_delta2"
# [360] "mactivos_margen_rank_delta3"
# [361] "mpasivos_margen_rank_delta1"
# [362] "mpasivos_margen_rank_delta2"
# [363] "mpasivos_margen_rank_delta3"
# [364] "mcuenta_corriente_rank_delta1"
# [365] "mcuenta_corriente_rank_delta2"
# [366] "mcuenta_corriente_rank_delta3"
# [367] "mcaja_ahorro_rank_delta1"
# [368] "mcaja_ahorro_rank_delta2"
# [369] "mcaja_ahorro_rank_delta3"
# [370] "mcuentas_saldo_rank_delta1"
# [371] "mcuentas_saldo_rank_delta2"
# [372] "mcuentas_saldo_rank_delta3"
# [373] "mtarjeta_visa_consumo_rank_delta1"
# [374] "mtarjeta_visa_consumo_rank_delta2"
# [375] "mtarjeta_visa_consumo_rank_delta3"
# [376] "mtarjeta_master_consumo_rank_delta1"
# [377] "mtarjeta_master_consumo_rank_delta2"
# [378] "mtarjeta_master_consumo_rank_delta3"
# [379] "mprestamos_personales_rank_delta1"
# [380] "mprestamos_personales_rank_delta2"
# [381] "mprestamos_personales_rank_delta3"
# [382] "mpayroll_rank_delta1"
# [383] "mpayroll_rank_delta2"
# [384] "mpayroll_rank_delta3"
# [385] "mttarjeta_visa_debitos_automaticos_rank_delta1"
# [386] "mttarjeta_visa_debitos_automaticos_rank_delta2"
# [387] "mttarjeta_visa_debitos_automaticos_rank_delta3"
# [388] "mcomisiones_mantenimiento_rank_delta1"
# [389] "mcomisiones_mantenimiento_rank_delta2"
# [390] "mcomisiones_mantenimiento_rank_delta3"
# [391] "mtransferencias_recibidas_rank_delta1"
# [392] "mtransferencias_recibidas_rank_delta2"
# [393] "mtransferencias_recibidas_rank_delta3"
# [394] "Master_mfinanciacion_limite_rank_delta1"
# [395] "Master_mfinanciacion_limite_rank_delta2"
# [396] "Master_mfinanciacion_limite_rank_delta3"
# [397] "Master_msaldototal_rank_delta1"
# [398] "Master_msaldototal_rank_delta2"
# [399] "Master_msaldototal_rank_delta3"
# [400] "Master_mlimitecompra_rank_delta1"
# [401] "Master_mlimitecompra_rank_delta2"
# [402] "Master_mlimitecompra_rank_delta3"
# [403] "Master_mconsumototal_rank_delta1"
# [404] "Master_mconsumototal_rank_delta2"
# [405] "Master_mconsumototal_rank_delta3"
# [406] "Master_mpagominimo_rank_delta1"
# [407] "Master_mpagominimo_rank_delta2"
# [408] "Master_mpagominimo_rank_delta3"
# [409] "Visa_mfinanciacion_limite_rank_delta1"
# [410] "Visa_mfinanciacion_limite_rank_delta2"
# [411] "Visa_mfinanciacion_limite_rank_delta3"
# [412] "Visa_msaldototal_rank_delta1"
# [413] "Visa_msaldototal_rank_delta2"
# [414] "Visa_msaldototal_rank_delta3"
# [415] "Visa_mlimitecompra_rank_delta1"
# [416] "Visa_mlimitecompra_rank_delta2"
# [417] "Visa_mlimitecompra_rank_delta3"
# [418] "Visa_mconsumototal_rank_delta1"
# [419] "Visa_mconsumototal_rank_delta2"
# [420] "Visa_mconsumototal_rank_delta3"
# [421] "Visa_mpagominimo_rank_delta1"
# [422] "Visa_mpagominimo_rank_delta2"
# [423] "Visa_mpagominimo_rank_delta3"
# [424] "kmes_delta1"
# [425] "kmes_delta2"
# [426] "kmes_delta3"
# [427] "ctrx_quarter_normalizado_delta1"
# [428] "ctrx_quarter_normalizado_delta2"
# [429] "ctrx_quarter_normalizado_delta3"
# [430] "foto_mes_formato_fecha_delta1"
# [431] "foto_mes_formato_fecha_delta2"
# [432] "foto_mes_formato_fecha_delta3"
# [433] "vm_status01_delta1"
# [434] "vm_status01_delta2"
# [435] "vm_status01_delta3"
# [436] "vm_status02_delta1"
# [437] "vm_status02_delta2"
# [438] "vm_status02_delta3"
# [439] "vm_status03_delta1"
# [440] "vm_status03_delta2"
# [441] "vm_status03_delta3"
# [442] "vm_status04_delta1"
# [443] "vm_status04_delta2"
# [444] "vm_status04_delta3"
# [445] "vm_status05_delta1"
# [446] "vm_status05_delta2"
# [447] "vm_status05_delta3"
# [448] "vm_status06_delta1"
# [449] "vm_status06_delta2"
# [450] "vm_status06_delta3"
# [451] "mv_status07_delta1"
# [452] "mv_status07_delta2"
# [453] "mv_status07_delta3"
# [454] "vm_Fvencimiento_delta1"
# [455] "vm_Fvencimiento_delta2"
# [456] "vm_Fvencimiento_delta3"
# [457] "vm_fultimo_cierre_delta1"
# [458] "vm_fultimo_cierre_delta2"
# [459] "vm_fultimo_cierre_delta3"
# [460] "vm_fechaalta_delta1"
# [461] "vm_fechaalta_delta2"
# [462] "vm_fechaalta_delta3"
# [463] "vm_cconsumos_delta1"
# [464] "vm_cconsumos_delta2"
# [465] "vm_cconsumos_delta3"

# %% [markdown]
# #### 9.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
VPOS_CORTE <- c()

fganancia_lgbm_meseta <- function(probs, datos) {
  vlabels <- get_field(datos, "label")
  vpesos <- get_field(datos, "weight")

  tbl <- as.data.table(list(
    "prob" = probs,
    "gan" = ifelse(vlabels == 1 & vpesos > 1, PARAM$CN$train$gan1, PARAM$CN$train$gan0)
  ))

  setorder(tbl, -prob)
  tbl[, posicion := .I]
  tbl[, gan_acum := cumsum(gan)]
  setorder(tbl, -gan_acum) # voy por la meseta

  gan <- mean(tbl[1:500, gan_acum]) # meseta de tamaño 500

  pos_meseta <- tbl[1:500, median(posicion)]
  VPOS_CORTE <<- c(VPOS_CORTE, pos_meseta)

  return(list(
    "name" = "ganancia",
    "value" = gan,
    "higher_better" = TRUE
  ))
}

# %%
# Elimina del dataset las variables que estan por debajo
#  de la capa geologica de canaritos
# se llama varias veces, luego de agregar muchas variables nuevas,
#  para ir reduciendo la cantidad de variables
# y así hacer lugar a nuevas variables importantes

GVEZ <- 1

campitos <- c( "numero_de_cliente", "foto_mes", "clase_ternaria" )

CanaritosAsesinos <- function(
  canaritos_ratio,
  canaritos_desvios,
  canaritos_semilla) {

  cat( "inicio CanaritosAsesinos()\n")
  gc(verbose= FALSE)
  dataset[, clase01 := 0L ]
  dataset[ clase_ternaria %in% PARAM$CN$train$clase01_valor1,
      clase01 := 1L ]

  set.seed(canaritos_semilla, kind = "L'Ecuyer-CMRG")
  for (i in 1:(ncol(dataset) * canaritos_ratio)) {
    dataset[, paste0("canarito", i) := runif(nrow(dataset))]
  }

  campos_buenos <- setdiff(
    colnames(dataset),
    c( campitos, "clase01")
  )

  azar <- runif(nrow(dataset))

  dataset[, entrenamiento :=
    as.integer( foto_mes %in% PARAM$CN$train$training &
      (clase01 == 1 | azar < PARAM$CN$train$undersampling))]

  dtrain <- lgb.Dataset(
    data = data.matrix(dataset[entrenamiento == TRUE, campos_buenos, with = FALSE]),
    label = dataset[entrenamiento == TRUE, clase01],
    weight = dataset[
      entrenamiento == TRUE,
      ifelse(clase_ternaria %in% PARAM$CN$train$positivos, 1.0000001, 1.0)
    ],
    free_raw_data = FALSE
  )

  dvalid <- lgb.Dataset(
    data = data.matrix(dataset[foto_mes %in% PARAM$CN$train$validation, campos_buenos, with = FALSE]),
    label = dataset[foto_mes %in% PARAM$CN$train$validation, clase01],
    weight = dataset[
      foto_mes %in% PARAM$CN$train$validation,
      ifelse( clase_ternaria %in% PARAM$CN$train$positivos, 1.0000001, 1.0)
    ],
    free_raw_data = FALSE
  )


  param <- list(
    objective = "binary",
    metric = "custom",
    first_metric_only = TRUE,
    boost_from_average = TRUE,
    feature_pre_filter = FALSE,
    verbosity = -100,
    seed = canaritos_semilla,
    max_depth = -1, # -1 significa no limitar,  por ahora lo dejo fijo
    min_gain_to_split = 0.0, # por ahora, lo dejo fijo
    lambda_l1 = 0.0, # por ahora, lo dejo fijo
    lambda_l2 = 0.0, # por ahora, lo dejo fijo
    max_bin = 31, # por ahora, lo dejo fijo
    num_iterations = 9999, # un numero grande, lo limita early_stopping_rounds
    force_row_wise = TRUE, # para que los alumnos no se atemoricen con  warning
    learning_rate = 0.065,
    feature_fraction = 1.0, # lo seteo en 1
    min_data_in_leaf = 260,
    num_leaves = 60,
    early_stopping_rounds = 200,
    num_threads = 1
  )

  set.seed(canaritos_semilla, kind = "L'Ecuyer-CMRG")
  modelo <- lgb.train(
    data = dtrain,
    valids = list(valid = dvalid),
    eval = fganancia_lgbm_meseta,
    param = param,
    verbose = -100
  )

  tb_importancia <- lgb.importance(model = modelo)
  tb_importancia[, pos := .I]

  fwrite(tb_importancia,
    file = paste0("impo_", GVEZ, ".txt"),
    sep = "\t"
  )

  GVEZ <<- GVEZ + 1

  umbral <- tb_importancia[
    Feature %like% "canarito",
    median(pos) + canaritos_desvios * sd(pos)
  ] # Atencion corto en la mediana mas desvios!!

  col_utiles <- tb_importancia[
    pos < umbral & !(Feature %like% "canarito"),
    Feature
  ]

  col_utiles <- unique(c(
    col_utiles,
    c(campitos, "mes")
  ))

  col_inutiles <- setdiff(colnames(dataset), col_utiles)

  dataset[, (col_inutiles) := NULL]

  cat( "fin CanaritosAsesinos()\n")

  return( tb_importancia )
}

# %%
# Estos DOS parametros son los que se deben modificar
PARAM$CN$ratio <- 0.2
PARAM$CN$desvios <- 2


# Parametros quasi fijos
# Parametros de un LightGBM que se genera para estimar la column importance
PARAM$CN$train$clase01_valor1 <- c( "BAJA+2", "BAJA+1")
PARAM$CN$train$positivos <- c( "BAJA+2")
PARAM$CN$train$training <- c( 202101, 202102, 202103)
PARAM$CN$train$validation <- c( 202105 )
PARAM$CN$train$undersampling <- 0.1
PARAM$CN$train$gan1 <- 117000
PARAM$CN$train$gan0 <-  -3000

# %%
# la llamada a Canaritos Asesinos
tb_importancia <- CanaritosAsesinos(
  canaritos_ratio = PARAM$CN$ratio,
  canaritos_desvios = PARAM$CN$desvios,
  canaritos_semilla = PARAM$semilla_primigenia
)
# Out:
# inicio CanaritosAsesinos()
# fin CanaritosAsesinos()

# %%
# grabo la importancia, ver el archivo directamente en la carpeta

fwrite( tb_importancia,
  file="canaritos.txt",
  sep="\t"
)

# %%
# verifico
ncol(dataset)
colnames(dataset)
# Out:
# [1] 258
#   [1] "numero_de_cliente"
#   [2] "foto_mes"
#   [3] "cliente_edad"
#   [4] "cliente_antiguedad"
#   [5] "cproductos"
#   [6] "cdescubierto_preacordado"
#   [7] "ctarjeta_visa_transacciones"
#   [8] "ctarjeta_master_transacciones"
#   [9] "cprestamos_personales"
#  [10] "cpayroll_trx"
#  [11] "ccomisiones_mantenimiento"
#  [12] "ccomisiones_otras"
#  [13] "ccallcenter_transacciones"
#  [14] "chomebanking_transacciones"
#  [15] "ctrx_quarter"
#  [16] "Master_Fvencimiento"
#  [17] "Master_fechaalta"
#  [18] "Visa_Fvencimiento"
#  [19] "Visa_cconsumos"
#  [20] "clase_ternaria"
#  [21] "mrentabilidad_rank"
#  [22] "mrentabilidad_annual_rank"
#  [23] "mcomisiones_rank"
#  [24] "mactivos_margen_rank"
#  [25] "mpasivos_margen_rank"
#  [26] "mcuenta_corriente_rank"
#  [27] "mcaja_ahorro_rank"
#  [28] "mcuentas_saldo_rank"
#  [29] "mtarjeta_visa_consumo_rank"
#  [30] "mtarjeta_master_consumo_rank"
#  [31] "mprestamos_personales_rank"
#  [32] "mpayroll_rank"
#  [33] "mttarjeta_visa_debitos_automaticos_rank"
#  [34] "mcomisiones_mantenimiento_rank"
#  [35] "mtransferencias_recibidas_rank"
#  [36] "Master_mfinanciacion_limite_rank"
#  [37] "Master_msaldototal_rank"
#  [38] "Master_mlimitecompra_rank"
#  [39] "Master_mconsumototal_rank"
#  [40] "Master_mpagominimo_rank"
#  [41] "Visa_mfinanciacion_limite_rank"
#  [42] "Visa_msaldototal_rank"
#  [43] "Visa_mlimitecompra_rank"
#  [44] "Visa_mconsumototal_rank"
#  [45] "Visa_mpagominimo_rank"
#  [46] "kmes"
#  [47] "ctrx_quarter_normalizado"
#  [48] "vm_status01"
#  [49] "vm_Fvencimiento"
#  [50] "cliente_edad_lag1"
#  [51] "cliente_antiguedad_lag1"
#  [52] "cproductos_lag1"
#  [53] "ctarjeta_visa_lag1"
#  [54] "ctarjeta_visa_transacciones_lag1"
#  [55] "cpayroll_trx_lag1"
#  [56] "ccomisiones_otras_lag1"
#  [57] "chomebanking_transacciones_lag1"
#  [58] "ctrx_quarter_lag1"
#  [59] "Master_Fvencimiento_lag1"
#  [60] "Master_fechaalta_lag1"
#  [61] "Master_cconsumos_lag1"
#  [62] "Visa_Fvencimiento_lag1"
#  [63] "Visa_fechaalta_lag1"
#  [64] "mrentabilidad_rank_lag1"
#  [65] "mrentabilidad_annual_rank_lag1"
#  [66] "mcomisiones_rank_lag1"
#  [67] "mactivos_margen_rank_lag1"
#  [68] "mpasivos_margen_rank_lag1"
#  [69] "mcuenta_corriente_rank_lag1"
#  [70] "mcaja_ahorro_rank_lag1"
#  [71] "mcuentas_saldo_rank_lag1"
#  [72] "mprestamos_personales_rank_lag1"
#  [73] "mpayroll_rank_lag1"
#  [74] "mttarjeta_visa_debitos_automaticos_rank_lag1"
#  [75] "mcomisiones_mantenimiento_rank_lag1"
#  [76] "mtransferencias_recibidas_rank_lag1"
#  [77] "Master_mlimitecompra_rank_lag1"
#  [78] "Master_mconsumototal_rank_lag1"
#  [79] "Master_mpagominimo_rank_lag1"
#  [80] "Visa_mfinanciacion_limite_rank_lag1"
#  [81] "Visa_msaldototal_rank_lag1"
#  [82] "Visa_mlimitecompra_rank_lag1"
#  [83] "Visa_mpagominimo_rank_lag1"
#  [84] "ctrx_quarter_normalizado_lag1"
#  [85] "vm_status01_lag1"
#  [86] "vm_Fvencimiento_lag1"
#  [87] "vm_fechaalta_lag1"
#  [88] "cliente_edad_lag2"
#  [89] "cliente_antiguedad_lag2"
#  [90] "cproductos_lag2"
#  [91] "ctarjeta_visa_transacciones_lag2"
#  [92] "ctarjeta_master_transacciones_lag2"
#  [93] "cpayroll_trx_lag2"
#  [94] "ccomisiones_otras_lag2"
#  [95] "chomebanking_transacciones_lag2"
#  [96] "ctrx_quarter_lag2"
#  [97] "Master_fultimo_cierre_lag2"
#  [98] "Master_fechaalta_lag2"
#  [99] "Master_cconsumos_lag2"
# [100] "Visa_Fvencimiento_lag2"
# [101] "Visa_fechaalta_lag2"
# [102] "Visa_cconsumos_lag2"
# [103] "mrentabilidad_annual_rank_lag2"
# [104] "mcomisiones_rank_lag2"
# [105] "mactivos_margen_rank_lag2"
# [106] "mpasivos_margen_rank_lag2"
# [107] "mcuenta_corriente_rank_lag2"
# [108] "mcaja_ahorro_rank_lag2"
# [109] "mcuentas_saldo_rank_lag2"
# [110] "mtarjeta_visa_consumo_rank_lag2"
# [111] "mprestamos_personales_rank_lag2"
# [112] "mpayroll_rank_lag2"
# [113] "mttarjeta_visa_debitos_automaticos_rank_lag2"
# [114] "mcomisiones_mantenimiento_rank_lag2"
# [115] "mtransferencias_recibidas_rank_lag2"
# [116] "Master_mfinanciacion_limite_rank_lag2"
# [117] "Master_mlimitecompra_rank_lag2"
# [118] "Master_mconsumototal_rank_lag2"
# [119] "Visa_mfinanciacion_limite_rank_lag2"
# [120] "Visa_msaldototal_rank_lag2"
# [121] "Visa_mlimitecompra_rank_lag2"
# [122] "Visa_mconsumototal_rank_lag2"
# [123] "Visa_mpagominimo_rank_lag2"
# [124] "ctrx_quarter_normalizado_lag2"
# [125] "vm_fultimo_cierre_lag2"
# [126] "vm_fechaalta_lag2"
# [127] "cliente_edad_lag3"
# [128] "cproductos_lag3"
# [129] "ctarjeta_visa_transacciones_lag3"
# [130] "cpayroll_trx_lag3"
# [131] "ccomisiones_mantenimiento_lag3"
# [132] "ccomisiones_otras_lag3"
# [133] "chomebanking_transacciones_lag3"
# [134] "ctrx_quarter_lag3"
# [135] "Master_Fvencimiento_lag3"
# [136] "Master_fechaalta_lag3"
# [137] "Visa_fechaalta_lag3"
# [138] "Visa_cconsumos_lag3"
# [139] "mrentabilidad_rank_lag3"
# [140] "mrentabilidad_annual_rank_lag3"
# [141] "mcomisiones_rank_lag3"
# [142] "mactivos_margen_rank_lag3"
# [143] "mpasivos_margen_rank_lag3"
# [144] "mcuenta_corriente_rank_lag3"
# [145] "mcaja_ahorro_rank_lag3"
# [146] "mcuentas_saldo_rank_lag3"
# [147] "mtarjeta_visa_consumo_rank_lag3"
# [148] "mprestamos_personales_rank_lag3"
# [149] "mpayroll_rank_lag3"
# [150] "mttarjeta_visa_debitos_automaticos_rank_lag3"
# [151] "mcomisiones_mantenimiento_rank_lag3"
# [152] "mtransferencias_recibidas_rank_lag3"
# [153] "Master_mfinanciacion_limite_rank_lag3"
# [154] "Master_mlimitecompra_rank_lag3"
# [155] "Master_mconsumototal_rank_lag3"
# [156] "Visa_mfinanciacion_limite_rank_lag3"
# [157] "Visa_msaldototal_rank_lag3"
# [158] "Visa_mlimitecompra_rank_lag3"
# [159] "Visa_mconsumototal_rank_lag3"
# [160] "Visa_mpagominimo_rank_lag3"
# [161] "kmes_lag3"
# [162] "ctrx_quarter_normalizado_lag3"
# [163] "vm_Fvencimiento_lag3"
# [164] "vm_fultimo_cierre_lag3"
# [165] "vm_fechaalta_lag3"
# [166] "vm_cconsumos_lag3"
# [167] "cproductos_delta1"
# [168] "cproductos_delta2"
# [169] "cproductos_delta3"
# [170] "ctarjeta_visa_transacciones_delta3"
# [171] "cprestamos_personales_delta3"
# [172] "cpayroll_trx_delta1"
# [173] "cpayroll_trx_delta2"
# [174] "ccomisiones_mantenimiento_delta1"
# [175] "ccomisiones_mantenimiento_delta2"
# [176] "ccomisiones_mantenimiento_delta3"
# [177] "ccomisiones_otras_delta2"
# [178] "ccomisiones_otras_delta3"
# [179] "ccallcenter_transacciones_delta1"
# [180] "ccallcenter_transacciones_delta3"
# [181] "chomebanking_transacciones_delta1"
# [182] "chomebanking_transacciones_delta2"
# [183] "chomebanking_transacciones_delta3"
# [184] "ctrx_quarter_delta1"
# [185] "ctrx_quarter_delta2"
# [186] "ctrx_quarter_delta3"
# [187] "Master_fultimo_cierre_delta2"
# [188] "Visa_cconsumos_delta1"
# [189] "Visa_cconsumos_delta2"
# [190] "Visa_cconsumos_delta3"
# [191] "mrentabilidad_rank_delta1"
# [192] "mrentabilidad_rank_delta2"
# [193] "mrentabilidad_rank_delta3"
# [194] "mrentabilidad_annual_rank_delta1"
# [195] "mrentabilidad_annual_rank_delta2"
# [196] "mrentabilidad_annual_rank_delta3"
# [197] "mcomisiones_rank_delta1"
# [198] "mcomisiones_rank_delta2"
# [199] "mcomisiones_rank_delta3"
# [200] "mactivos_margen_rank_delta1"
# [201] "mactivos_margen_rank_delta2"
# [202] "mactivos_margen_rank_delta3"
# [203] "mpasivos_margen_rank_delta1"
# [204] "mpasivos_margen_rank_delta2"
# [205] "mpasivos_margen_rank_delta3"
# [206] "mcuenta_corriente_rank_delta2"
# [207] "mcaja_ahorro_rank_delta1"
# [208] "mcaja_ahorro_rank_delta2"
# [209] "mcaja_ahorro_rank_delta3"
# [210] "mcuentas_saldo_rank_delta1"
# [211] "mcuentas_saldo_rank_delta2"
# [212] "mcuentas_saldo_rank_delta3"
# [213] "mtarjeta_visa_consumo_rank_delta1"
# [214] "mtarjeta_visa_consumo_rank_delta2"
# [215] "mtarjeta_visa_consumo_rank_delta3"
# [216] "mtarjeta_master_consumo_rank_delta1"
# [217] "mprestamos_personales_rank_delta1"
# [218] "mprestamos_personales_rank_delta3"
# [219] "mpayroll_rank_delta1"
# [220] "mpayroll_rank_delta2"
# [221] "mttarjeta_visa_debitos_automaticos_rank_delta2"
# [222] "mttarjeta_visa_debitos_automaticos_rank_delta3"
# [223] "mcomisiones_mantenimiento_rank_delta1"
# [224] "mcomisiones_mantenimiento_rank_delta2"
# [225] "mcomisiones_mantenimiento_rank_delta3"
# [226] "mtransferencias_recibidas_rank_delta2"
# [227] "Master_mfinanciacion_limite_rank_delta1"
# [228] "Master_mfinanciacion_limite_rank_delta2"
# [229] "Master_mfinanciacion_limite_rank_delta3"
# [230] "Master_msaldototal_rank_delta1"
# [231] "Master_msaldototal_rank_delta3"
# [232] "Master_mlimitecompra_rank_delta1"
# [233] "Master_mlimitecompra_rank_delta2"
# [234] "Master_mlimitecompra_rank_delta3"
# [235] "Master_mconsumototal_rank_delta1"
# [236] "Master_mconsumototal_rank_delta2"
# [237] "Master_mconsumototal_rank_delta3"
# [238] "Visa_mfinanciacion_limite_rank_delta1"
# [239] "Visa_msaldototal_rank_delta1"
# [240] "Visa_msaldototal_rank_delta2"
# [241] "Visa_msaldototal_rank_delta3"
# [242] "Visa_mlimitecompra_rank_delta1"
# [243] "Visa_mlimitecompra_rank_delta2"
# [244] "Visa_mlimitecompra_rank_delta3"
# [245] "Visa_mconsumototal_rank_delta1"
# [246] "Visa_mconsumototal_rank_delta2"
# [247] "Visa_mconsumototal_rank_delta3"
# [248] "Visa_mpagominimo_rank_delta1"
# [249] "Visa_mpagominimo_rank_delta3"
# [250] "ctrx_quarter_normalizado_delta1"
# [251] "ctrx_quarter_normalizado_delta2"
# [252] "ctrx_quarter_normalizado_delta3"
# [253] "vm_status01_delta1"
# [254] "vm_status03_delta3"
# [255] "vm_status04_delta2"
# [256] "vm_fultimo_cierre_delta2"
# [257] "vm_cconsumos_delta2"
# [258] "vm_cconsumos_delta3"

# %% [markdown]
# ### 9.3.2 Modelado

# %% [markdown]
# #### 9.3.2.1 Training Strategy

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202109  obviamente completo
#
# * final_train =  [ 201901, 202107 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202107   completo, sin undersampling
#    * training = [ 201901, 202105 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202107)

PARAM$trainingstrategy$training <- c(
  201901, 201902, 201903, 201904, 201905, 201906,
  201907, 201908, 201909, 201910, 201911, 201912,
  202001, 202002, 202003, 202004, 202005, 202006,
  202007, 202008, 202009, 202010, 202011, 202012,
  202101, 202102, 202103, 202104, 202105
)


PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 33053

# %% [markdown]
# ####  9.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# un Analista Jr  debe poder animarse a hacer 100 iteraciones
PARAM$hipeparametertuning$num_interations <- 50

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  seed= PARAM$semilla_primigenia,
  max_bin= 31,

  num_iterations= 9999,  # valor grande, lo limita early_stopping_rounds
  early_stopping_rounds= 400
)

PARAM$hipeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_leaves", lower= 2L, upper= 256L),
  makeIntegerParam("min_data_in_leaf", lower= 2L, upper= 8192L),
  makeNumericParam("feature_fraction", lower= 0.1, upper= 0.7),
  makeNumericParam("learning_rate", lower= 0.005, upper= 0.4)
)

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Sun Nov 30 22:07:27 2025 AUC 0.917217440943203
#
# Sun Nov 30 22:08:19 2025 AUC 0.917257764743918
#
# Sun Nov 30 22:08:52 2025 AUC 0.919942186271896
#
# Sun Nov 30 22:10:11 2025 AUC 0.923419444005667
#
# Sun Nov 30 22:11:13 2025 AUC 0.927423412773008
#
# Sun Nov 30 22:12:00 2025 AUC 0.928052511714153
#
# Sun Nov 30 22:13:28 2025 AUC 0.931738595511895
#
# Sun Nov 30 22:15:02 2025 AUC 0.918011200367477
#
# Sun Nov 30 22:15:56 2025 AUC 0.915684689797399
#
# Sun Nov 30 22:16:52 2025 AUC 0.920508893512526
#
# Sun Nov 30 22:17:47 2025 AUC 0.926728914225975
#
# Sun Nov 30 22:18:57 2025 AUC 0.895200467065164
#
# Sun Nov 30 22:19:24 2025 AUC 0.928187242049779
#
# Sun Nov 30 22:20:17 2025 AUC 0.928129942941524
#
# Sun Nov 30 22:22:25 2025 AUC 0.930142976165715
#
# Sun Nov 30 22:22:51 2025 AUC 0.916614489931915
#
# [mbo] 0: num_leaves=183; min_data_in_leaf=2126; feature_fraction=0.355; learning_rate=0.299 : y = 0.917 : 79.0 secs : initdesign
#
# [mbo] 0: num_leaves=122; min_data_in_leaf=3337; feature_fraction=0.296; learning_rate=0.321 : y = 0.917 : 52.3 secs : initdesign
#
# [mbo] 0: num_leaves=109; min_data_in_leaf=2950; feature_fraction=0.193; learning_rate=0.167 : y = 0.92 : 33.5 secs : initdesign
#
# [mbo] 0: num_leaves=140; min_data_in_leaf=6385; feature_fraction=0.56; learning_rate=0.257 : y = 0.923 : 78.5 secs : initdesign
#
# [mbo] 0: num_leaves=80; min_data_in_leaf=1642; feature_fraction=0.498; learning_rate=0.0742 : y = 0.927 : 61.7 secs : initdesign
#
# [mbo] 0: num_leaves=26; min_data_in_leaf=7605; feature_fraction=0.418; learning_rate=0.116 : y = 0.928 : 47.6 secs : initdesign
#
# [mbo] 0: num_leaves=148; min_data_in_leaf=5134; feature_fraction=0.39; learning_rate=0.027 : y = 0.932 : 87.8 secs : initdesign
#
# [mbo] 0: num_leaves=236; min_data_in_leaf=6139; feature_fraction=0.696; learning_rate=0.383 : y = 0.918 : 94.1 secs : initdesign
#
# [mbo] 0: num_leaves=41; min_data_in_leaf=1314; feature_fraction=0.606; learning_rate=0.217 : y = 0.916 : 53.7 secs : initdesign
#
# [mbo] 0: num_leaves=215; min_data_in_leaf=4111; feature_fraction=0.221; learning_rate=0.239 : y = 0.921 : 55.7 secs : initdesign
#
# [mbo] 0: num_leaves=51; min_data_in_leaf=4942; feature_fraction=0.447; learning_rate=0.191 : y = 0.927 : 55.3 secs : initdesign
#
# [mbo] 0: num_leaves=207; min_data_in_leaf=299; feature_fraction=0.535; learning_rate=0.347 : y = 0.895 : 69.9 secs : initdesign
#
# [mbo] 0: num_leaves=165; min_data_in_leaf=7999; feature_fraction=0.127; learning_rate=0.131 : y = 0.928 : 27.0 secs : initdesign
#
# [mbo] 0: num_leaves=9; min_data_in_leaf=730; feature_fraction=0.277; learning_rate=0.0508 : y = 0.928 : 52.9 secs : initdesign
#
# [mbo] 0: num_leaves=247; min_data_in_leaf=6907; feature_fraction=0.633; learning_rate=0.0795 : y = 0.93 : 128.6 secs : initdesign
#
# [mbo] 0: num_leaves=95; min_data_in_leaf=3719; feature_fraction=0.138; learning_rate=0.368 : y = 0.917 : 26.0 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Sun Nov 30 22:34:20 2025 AUC 0.917828135077227
#
# [mbo] 1: num_leaves=2; min_data_in_leaf=5361; feature_fraction=0.698; learning_rate=0.00504 : y = 0.918 : 685.8 secs : infill_ei
#
# Saved the current state after iteration 2 in the file HT.RDATA.
#
# Sun Nov 30 22:35:32 2025 AUC 0.932534469404301
#
# [mbo] 2: num_leaves=256; min_data_in_leaf=6645; feature_fraction=0.346; learning_rate=0.0545 : y = 0.933 : 70.6 secs : infill_ei
#
# Sun Nov 30 22:36:59 2025 AUC 0.929611797945952
#
# [mbo] 3: num_leaves=256; min_data_in_leaf=5583; feature_fraction=0.385; learning_rate=0.083 : y = 0.93 : 85.6 secs : infill_ei
#
# Sun Nov 30 22:40:49 2025 AUC 0.931686657027075
#
# [mbo] 4: num_leaves=256; min_data_in_leaf=7456; feature_fraction=0.428; learning_rate=0.00516 : y = 0.932 : 229.2 secs : infill_ei
#
# Sun Nov 30 22:51:20 2025 AUC 0.917764701033266
#
# [mbo] 5: num_leaves=2; min_data_in_leaf=1862; feature_fraction=0.347; learning_rate=0.0051 : y = 0.918 : 631.2 secs : infill_ei
#
# Saved the current state after iteration 6 in the file HT.RDATA.
#
# Sun Nov 30 22:51:58 2025 AUC 0.929694589796756
#
# [mbo] 6: num_leaves=181; min_data_in_leaf=8185; feature_fraction=0.112; learning_rate=0.0395 : y = 0.93 : 35.0 secs : infill_ei
#
# Sun Nov 30 22:53:30 2025 AUC 0.932086321285273
#
# [mbo] 7: num_leaves=256; min_data_in_leaf=5835; feature_fraction=0.449; learning_rate=0.0326 : y = 0.932 : 91.5 secs : infill_ei
#
# Sun Nov 30 22:54:38 2025 AUC 0.930771658169483
#
# [mbo] 8: num_leaves=167; min_data_in_leaf=6286; feature_fraction=0.373; learning_rate=0.0524 : y = 0.931 : 68.1 secs : infill_ei
#
# Sun Nov 30 22:55:16 2025 AUC 0.928288796082599
#
# [mbo] 9: num_leaves=245; min_data_in_leaf=5070; feature_fraction=0.101; learning_rate=0.0264 : y = 0.928 : 36.5 secs : infill_ei
#
# Sun Nov 30 22:56:45 2025 AUC 0.932082747536317
#
# [mbo] 10: num_leaves=256; min_data_in_leaf=7322; feature_fraction=0.39; learning_rate=0.0426 : y = 0.932 : 88.4 secs : infill_ei
#
# Sun Nov 30 22:59:18 2025 AUC 0.930574089414722
#
# [mbo] 11: num_leaves=206; min_data_in_leaf=7397; feature_fraction=0.7; learning_rate=0.02 : y = 0.931 : 152.8 secs : infill_ei
#
# Sun Nov 30 23:01:10 2025 AUC 0.923360298460453
#
# [mbo] 12: num_leaves=256; min_data_in_leaf=175; feature_fraction=0.616; learning_rate=0.052 : y = 0.923 : 111.1 secs : infill_ei
#
# Sun Nov 30 23:01:35 2025 AUC 0.917802940147091
#
# [mbo] 13: num_leaves=2; min_data_in_leaf=8183; feature_fraction=0.105; learning_rate=0.189 : y = 0.918 : 24.1 secs : infill_ei
#
# Saved the current state after iteration 14 in the file HT.RDATA.
#
# Sun Nov 30 23:03:20 2025 AUC 0.932571993768335
#
# [mbo] 14: num_leaves=226; min_data_in_leaf=6855; feature_fraction=0.301; learning_rate=0.0163 : y = 0.933 : 103.5 secs : infill_ei
#
# Sun Nov 30 23:04:58 2025 AUC 0.93049707512473
#
# [mbo] 15: num_leaves=195; min_data_in_leaf=4452; feature_fraction=0.505; learning_rate=0.0469 : y = 0.93 : 97.5 secs : infill_ei
#
# Sun Nov 30 23:06:37 2025 AUC 0.927154160570447
#
# [mbo] 16: num_leaves=256; min_data_in_leaf=8187; feature_fraction=0.62; learning_rate=0.137 : y = 0.927 : 97.6 secs : infill_ei
#
# Sun Nov 30 23:08:17 2025 AUC 0.930347156356044
#
# [mbo] 17: num_leaves=256; min_data_in_leaf=6640; feature_fraction=0.433; learning_rate=0.0245 : y = 0.93 : 99.7 secs : infill_ei
#
# Sun Nov 30 23:11:28 2025 AUC 0.931988043188994
#
# [mbo] 18: num_leaves=196; min_data_in_leaf=6560; feature_fraction=0.342; learning_rate=0.0055 : y = 0.932 : 190.6 secs : infill_ei
#
# Sun Nov 30 23:14:10 2025 AUC 0.93188112853274
#
# [mbo] 19: num_leaves=208; min_data_in_leaf=7528; feature_fraction=0.274; learning_rate=0.00848 : y = 0.932 : 161.2 secs : infill_ei
#
# Saved the current state after iteration 20 in the file HT.RDATA.
#
# Sun Nov 30 23:15:45 2025 AUC 0.931370201557059
#
# [mbo] 20: num_leaves=218; min_data_in_leaf=5959; feature_fraction=0.404; learning_rate=0.0364 : y = 0.931 : 92.8 secs : infill_ei
#
# Sun Nov 30 23:18:23 2025 AUC 0.931892802779328
#
# [mbo] 21: num_leaves=256; min_data_in_leaf=5346; feature_fraction=0.322; learning_rate=0.0106 : y = 0.932 : 157.3 secs : infill_ei
#
# Sun Nov 30 23:19:08 2025 AUC 0.930748250113824
#
# [mbo] 22: num_leaves=256; min_data_in_leaf=7204; feature_fraction=0.227; learning_rate=0.0653 : y = 0.931 : 44.5 secs : infill_ei
#
# Sun Nov 30 23:20:11 2025 AUC 0.930023255575704
#
# [mbo] 23: num_leaves=201; min_data_in_leaf=7878; feature_fraction=0.355; learning_rate=0.0563 : y = 0.93 : 62.0 secs : infill_ei
#
# Sun Nov 30 23:21:17 2025 AUC 0.931048087651196
#
# [mbo] 24: num_leaves=254; min_data_in_leaf=5624; feature_fraction=0.315; learning_rate=0.0406 : y = 0.931 : 65.6 secs : infill_ei
#
# Sun Nov 30 23:23:22 2025 AUC 0.930164716471862
#
# [mbo] 25: num_leaves=256; min_data_in_leaf=6635; feature_fraction=0.697; learning_rate=0.0517 : y = 0.93 : 124.1 secs : infill_ei
#
# Sun Nov 30 23:25:10 2025 AUC 0.929811570512568
#
# [mbo] 26: num_leaves=158; min_data_in_leaf=6867; feature_fraction=0.102; learning_rate=0.00503 : y = 0.93 : 107.1 secs : infill_ei
#
# Saved the current state after iteration 27 in the file HT.RDATA.
#
# Sun Nov 30 23:26:55 2025 AUC 0.931167033928934
#
# [mbo] 27: num_leaves=256; min_data_in_leaf=5037; feature_fraction=0.463; learning_rate=0.0321 : y = 0.931 : 102.4 secs : infill_ei
#
# Sun Nov 30 23:29:20 2025 AUC 0.931594513866503
#
# [mbo] 28: num_leaves=198; min_data_in_leaf=5833; feature_fraction=0.393; learning_rate=0.0148 : y = 0.932 : 144.8 secs : infill_ei
#
# Sun Nov 30 23:30:57 2025 AUC 0.93250987009899
#
# [mbo] 29: num_leaves=138; min_data_in_leaf=6897; feature_fraction=0.375; learning_rate=0.0317 : y = 0.933 : 96.3 secs : infill_ei
#
# Sun Nov 30 23:32:36 2025 AUC 0.928091346452804
#
# [mbo] 30: num_leaves=184; min_data_in_leaf=7363; feature_fraction=0.659; learning_rate=0.109 : y = 0.928 : 98.5 secs : infill_ei
#
# Sun Nov 30 23:36:58 2025 AUC 0.932105440842185
#
# [mbo] 31: num_leaves=134; min_data_in_leaf=7243; feature_fraction=0.337; learning_rate=0.00502 : y = 0.932 : 260.6 secs : infill_ei
#
# Saved the current state after iteration 32 in the file HT.RDATA.
#
# Sun Nov 30 23:38:15 2025 AUC 0.932534767216714
#
# [mbo] 32: num_leaves=249; min_data_in_leaf=6926; feature_fraction=0.34; learning_rate=0.0391 : y = 0.933 : 75.3 secs : infill_ei
#
# Sun Nov 30 23:39:18 2025 AUC 0.929879293055277
#
# [mbo] 33: num_leaves=165; min_data_in_leaf=6791; feature_fraction=0.317; learning_rate=0.0533 : y = 0.93 : 62.2 secs : infill_ei
#
# Sun Nov 30 23:42:59 2025 AUC 0.932040577298641
#
# [mbo] 34: num_leaves=256; min_data_in_leaf=7296; feature_fraction=0.328; learning_rate=0.00514 : y = 0.932 : 220.0 secs : infill_ei
#
# Sun Nov 30 23:45:59 2025 AUC 0.930482124941599
#
# [mbo] 35: num_leaves=140; min_data_in_leaf=6982; feature_fraction=0.599; learning_rate=0.0147 : y = 0.93 : 179.7 secs : infill_ei
#
# Sun Nov 30 23:49:01 2025 AUC 0.931808700553907
#
# [mbo] 36: num_leaves=99; min_data_in_leaf=7692; feature_fraction=0.489; learning_rate=0.0096 : y = 0.932 : 181.2 secs : infill_ei
#
# Saved the current state after iteration 37 in the file HT.RDATA.
#
# Sun Nov 30 23:54:41 2025 AUC 0.931768912815535
#
# [mbo] 37: num_leaves=125; min_data_in_leaf=5603; feature_fraction=0.456; learning_rate=0.00638 : y = 0.932 : 337.9 secs : infill_ei
#
# Sun Nov 30 23:56:06 2025 AUC 0.929274019107168
#
# [mbo] 38: num_leaves=256; min_data_in_leaf=6700; feature_fraction=0.498; learning_rate=0.0611 : y = 0.929 : 83.4 secs : infill_ei
#
# Sun Nov 30 23:57:34 2025 AUC 0.930459908135592
#
# [mbo] 39: num_leaves=254; min_data_in_leaf=8173; feature_fraction=0.344; learning_rate=0.0333 : y = 0.93 : 87.2 secs : infill_ei
#
# Sun Nov 30 23:59:26 2025 AUC 0.931546327818086
#
# [mbo] 40: num_leaves=110; min_data_in_leaf=6821; feature_fraction=0.368; learning_rate=0.0195 : y = 0.932 : 111.5 secs : infill_ei
#
# Saved the current state after iteration 41 in the file HT.RDATA.
#
# Mon Dec 01 00:01:34 2025 AUC 0.931794703370498
#
# [mbo] 41: num_leaves=256; min_data_in_leaf=6612; feature_fraction=0.237; learning_rate=0.00507 : y = 0.932 : 126.3 secs : infill_ei
#
# Mon Dec 01 00:09:03 2025 AUC 0.930797389161963
#
# [mbo] 42: num_leaves=256; min_data_in_leaf=5670; feature_fraction=0.608; learning_rate=0.00544 : y = 0.931 : 447.5 secs : infill_ei
#
# Mon Dec 01 00:11:03 2025 AUC 0.931974999005307
#
# [mbo] 43: num_leaves=107; min_data_in_leaf=5292; feature_fraction=0.464; learning_rate=0.0321 : y = 0.932 : 119.2 secs : infill_ei
#
# Saved the current state after iteration 44 in the file HT.RDATA.
#
# Mon Dec 01 00:11:37 2025 AUC 0.928285520146057
#
# [mbo] 44: num_leaves=256; min_data_in_leaf=7994; feature_fraction=0.15; learning_rate=0.0983 : y = 0.928 : 31.6 secs : infill_ei
#
# Mon Dec 01 00:13:38 2025 AUC 0.929881258617202
#
# [mbo] 45: num_leaves=256; min_data_in_leaf=6955; feature_fraction=0.656; learning_rate=0.0334 : y = 0.93 : 120.5 secs : infill_ei
#
# Mon Dec 01 00:17:15 2025 AUC 0.930859036331447
#
# [mbo] 46: num_leaves=139; min_data_in_leaf=7512; feature_fraction=0.412; learning_rate=0.00798 : y = 0.931 : 216.1 secs : infill_ei
#
# Mon Dec 01 00:18:10 2025 AUC 0.92897084607077
#
# [mbo] 47: num_leaves=256; min_data_in_leaf=7227; feature_fraction=0.357; learning_rate=0.132 : y = 0.929 : 54.2 secs : infill_ei
#
# Mon Dec 01 00:20:06 2025 AUC 0.93045734694884
#
# [mbo] 48: num_leaves=134; min_data_in_leaf=5383; feature_fraction=0.513; learning_rate=0.0468 : y = 0.93 : 114.8 secs : infill_ei
#
# Mon Dec 01 00:21:14 2025 AUC 0.930320472363842
#
# [mbo] 49: num_leaves=256; min_data_in_leaf=6281; feature_fraction=0.332; learning_rate=0.0389 : y = 0.93 : 67.7 secs : infill_ei
#
# Saved the current state after iteration 50 in the file HT.RDATA.
#
# Mon Dec 01 00:27:30 2025 AUC 0.931031469718553
#
# [mbo] 50: num_leaves=241; min_data_in_leaf=7995; feature_fraction=0.563; learning_rate=0.00502 : y = 0.931 : 373.5 secs : infill_ei
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves min_data_in_leaf feature_fraction learning_rate num_iterations
#         <int>            <int>            <num>         <num>          <int>
# 1:        226             6855        0.3008075    0.01627382            537

# %% [markdown]
# ### 9.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  201901, 201902, 201903, 201904, 201905, 201906,
  201907, 201908, 201909, 201910, 201911, 201912,
  202001, 202002, 202003, 202004, 202005, 202006,
  202007, 202008, 202009, 202010, 202011, 202012,
  202101, 202102, 202103, 202104, 202105, 202106,
  202107
)


dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 910211

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
PARAM$FT$semillerio <- 20  # cantidad de semillas

# %%
if(!require("primes")) install.packages("primes")
require("primes")
# Out:
# Loading required package: primes

# %%
primos <- generate_primes(min = 100000, max = 1000000)
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
# me quedo con PARAM$semillerio  primos al azar
PARAM$FT$semillas <- sample(primos)[seq(PARAM$FT$semillerio)]

cat( PARAM$FT$semillas)
# Out:
# 533713 492491 425281 750313 185063 329111 454543 125471 322523 520393 218143 700459 568153 479701 557663 494959 859267 811771 641549 582161

# %%
dir.create("modelos", showWarnings =FALSE)

primero <- TRUE
for( sem in PARAM$FT$semillas)
{
  nombre_arch <- paste0( "./modelos/modelo_", sem, ".txt")
  if( !file.exists(nombre_arch) )
  {
    param_final$seed <- sem

    set.seed(sem, kind = "L'Ecuyer-CMRG")
    final_model <- lgb.train(
      data= dfinal_train,
      param= param_final,
      verbose= -100
    )

    lgb.save(final_model, nombre_arch) # grabo el modelo"

    # grabo la primer importancia de variables
    #  Natalia : da lo mismo cual se guarda
    if( primero)
    {
      primero <- FALSE
      tb_importancia <- as.data.table(lgb.importance(final_model))
      archivo_importancia <- "impo.txt"

      fwrite( tb_importancia,
        file= archivo_importancia,
        sep= "\t"
      )
    }
 }
}

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202109)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := 0]

datos_matrix <- data.matrix(dfuture[, campos_buenos, with= FALSE])

for( isem in seq(length(PARAM$FT$semillas)) )
{
   sem <- PARAM$FT$semillas[ isem ]
   nombre_arch <- paste0( "./modelos/modelo_", sem, ".txt")
   final_model <- lgb.load(nombre_arch)
   prediccion <- predict(
     final_model,
     datos_matrix
  )

  tb_prediccion[, paste0("prob_", isem) := prediccion]
  tb_prediccion[, prob := prob + prediccion]

  rm(final_model)
  rm(prediccion)
  gc(full = TRUE, verbose=FALSE)
}

rm( datos_matrix)
gc(full = TRUE, verbose=FALSE)

tb_prediccion[, prob := prob /length(PARAM$FT$semillas) ]
# Out:
#        used      (Mb)   gc trigger (Mb)   max used  (Mb)
# Ncells   2750539  146.9   7762177   414.6   7762177  414.6
# Vcells 228803194 1745.7 621037685  4738.2 768728974 5865.0

# %% [markdown]
# ##### Tabla Prediccion

# %%
# veo que hay en tb_prediccion
tb_prediccion
# Out:
#       numero_de_cliente prob         prob_1       prob_2       prob_3
# 1     29186441          0.